# %% [markdown]
# # Transfer data between MongoDB and SQL database. Map-reduce in MongoDB

# %% [markdown]
# **Tasks to complete:**
# * Import "reviews_electronics.16.json" file into MongoDB.
#
# * Create a SQL database and table and import each document from the collection into the SQL table.
#
# * Map reduce to create collection "avg_scores" by product.
#
# * Map reduce to create collection "weighted_avg_score" by product.

# %% [markdown]
# ## Import data into MongoDB
# Create a collection called “electronics” in “amazon” that contains each line of “reviews_electronics.16.json” as an individual document.

# %%
import pandas as pd
from pymongo import MongoClient
import json
from bson.code import Code
import pymysql
from tqdm import tqdm
import re
from bs4 import BeautifulSoup as bs 
from datetime import datetime

# %%
# Connect to the MongoDB and create collection "electronics" in "amazon" database.
client = MongoClient('localhost', 27017)
db = client['amazon']
coll = db['electronics']

# %%
data = []
with open('reviews_electronics.16.json', encoding="UTF-8") as json_f:
    for line in json_f:
        data.append(json.loads(line))
    coll.insert_many(data)

# %%
# check if the database exists
dblist = client.list_database_names()
if "amazon" in dblist:
    print("The database exists.")
# Out:
# The database exists.

# %% [markdown]
# Write code that reads all documents in “electronics”, and prints the first 25 documents to screen.

# %%
results = coll.find()
for result in results[:25]:
     print(result)
# Out:
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371b6'), 'reviewerID': 'AKM1MP6P0OYPR', 'asin': '0132793040', 'reviewerName': 'Vicki Gibson "momo4"', 'helpful': [1, 1], 'reviewText': 'Corey Barker does a great job of explaining Blend Modes in this DVD. All of the Kelby training videos are great but pricey to buy individually. If you really want bang for your buck just subscribe to Kelby Training online.', 'overall': 5.0, 'summary': 'Very thorough', 'unixReviewTime': 1365811200, 'reviewTime': '04 13, 2013'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371b7'), 'reviewerID': 'A2X8VX4DPMQFQQ', 'asin': 'B00E4KP4W6', 'reviewerName': 'lily68', 'helpful': [1, 1], 'reviewText': "I can't believe I waited to long to switch to a glass screen protector.  I love this.  It feels and looks like there is no protector on.  It does show fingerprints, which I think is inevitable unless you use a matte finish screen protector, but they wipe right away. I would definitely recommend this! Easier to apply than the films too!", 'overall': 5.0, 'summary': 'LOVE this screen protector!!', 'unixReviewTime': 1393459200, 'reviewTime': '02 27, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371b8'), 'reviewerID': 'A1JEKX4D58576X', 'asin': 'B00E4KP4W6', 'reviewerName': 'Mara Milagros', 'helpful': [2, 2], 'reviewText': 'presentation of product is beautiful, everything is perfect! And my iPad screen seems to be really protected. I recommend it.', 'overall': 5.0, 'summary': 'excellent', 'unixReviewTime': 1394496000, 'reviewTime': '03 11, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371b9'), 'reviewerID': 'ATM6RRB90D8DV', 'asin': 'B00E4KP4W6', 'reviewerName': 'Matthew D. Irmen "Jazz Fan"', 'helpful': [1, 2], 'reviewText': "I bought this screen protector because I was unimpressed with the Otterbox Defender attached screen protector. If I have a retina display iPad, I want it to look like it has retina display, not a hazy iPad 2. So... I started researching and came across this tempered glass screen protector with promises of easy installation and beautiful retina quality display. I have to admit that I am very impressed with the picture quality and the ease of installation. Best of all, I was able to tear out the plastic screen protector from my Otterbox defender case and use the case without issue. So why did I give it 4 stars? Because of the home button sticker! The sticker is a lame plastic blob that sits on the home button and looks ugly. I thought little of it because I would bury it under the frame of the Otterbox case. Unfortunately it causes slight problems with the use of the home button. If I press for slightly too long (a second) it activates siri. Believe me it's not the end of the world and I love how the screen looks it's just a minor issue that justifies 4 stars.", 'overall': 4.0, 'summary': 'Nice looking, easy to install glass screen protector that works beautifully with the Otterbox Defender.', 'unixReviewTime': 1393891200, 'reviewTime': '03 4, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371ba'), 'reviewerID': 'A3QOYJ97A6OMX7', 'asin': 'B00E4KP4W6', 'reviewerName': 'pharmdaddyd', 'helpful': [1, 1], 'reviewText': 'this is a great screen protector for the price, not as expensive as others and just as good as name brands', 'overall': 5.0, 'summary': 'great for the price', 'unixReviewTime': 1388361600, 'reviewTime': '12 30, 2013'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371bb'), 'reviewerID': 'AWO84NZ6VDYR2', 'asin': 'B00E4KP4W6', 'reviewerName': 'shalane rogillio', 'helpful': [0, 0], 'reviewText': 'I ordered two of these &#34;shatter proof&#34; protector for iPad s.  One arrived broken. Amazon refunded and ordered another one just like it.  Using the flat plastic tool to push bubbles out, the edge of this chipped.  This is definitely not up breakable and when it does break it is in big shards.  So from the 3 I have touched, only one is perfect.', 'overall': 1.0, 'summary': 'Not happy with this, would not recommend', 'unixReviewTime': 1404777600, 'reviewTime': '07 8, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371bc'), 'reviewerID': 'A15ZEBTKX72NPB', 'asin': 'B00E4KP4W6', 'reviewerName': 'S. Marcus "pdtpoet"', 'helpful': [1, 2], 'reviewText': "For some reasons, the clear film screens that other people like have short lives on my devices...they begin to curl or bubble or peel within a week or 2 of application, and look terrible.  The only film screen that stayed on my ipad blurred my view of the screen a little bit, which was a constant annoyance.  Putting a tempered glass screen on my iphone 5 solved all those problems so well that I replaced the plastic screen on my iPad 2 with this WOPUTUO tempered glass screen protector.  Application was easy and there were no bubbles in the viewing area at all!  The screen is wonderfully clear so I can finally see the full resolution of the iPad screen.  I'm only sorry I did not use the tempered glass screen when I first bought my iPad!", 'overall': 5.0, 'summary': 'Far better than film screens for iPhone or iPad!', 'unixReviewTime': 1392249600, 'reviewTime': '02 13, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371bd'), 'reviewerID': 'A2ZI014DO0LWEW', 'asin': 'B00E4KP4W6', 'reviewerName': 'SueinCa', 'helpful': [0, 0], 'reviewText': 'This was just what the doctor ordered for my broken screen and i could not afford replacement and this is next best thing and perfect.', 'overall': 5.0, 'summary': 'Right On', 'unixReviewTime': 1397174400, 'reviewTime': '04 11, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371be'), 'reviewerID': 'A3IN9CE5GG8VKR', 'asin': 'B00E4KP4W6', 'reviewerName': 'Tess Brown', 'helpful': [0, 0], 'reviewText': 'This is the best screen protector.  Very smooth feel! Looks incredible. Takes a little skill to put on but no air bubbles at all!', 'overall': 5.0, 'summary': 'Tempered Glass Screen Protector', 'unixReviewTime': 1399593600, 'reviewTime': '05 9, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371bf'), 'reviewerID': 'A1U9ZR7HQ5EZ6L', 'asin': 'B00E4KP4W6', 'reviewerName': 'Thinker623', 'helpful': [1, 1], 'reviewText': 'Great glass cover for IPad.  I had been using ones that are top screen protector made of plastic.  I dropped my IpadAnd had a dent in protector.  I heard about these tempered glass protectors from my son.  They priced at $60.  This one was much cheaper and works great.  Cannot believe the quality difference between glass and the plastic.', 'overall': 5.0, 'summary': 'Great glass cover for IPad.', 'unixReviewTime': 1391126400, 'reviewTime': '01 31, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c0'), 'reviewerID': 'A2DFGG75NH91H2', 'asin': 'B00E4KP4W6', 'reviewerName': 'Thuddds', 'helpful': [0, 0], 'reviewText': 'Glass screen protectors are a drastic improvement over plastic film protectors.  The glass fits perfectly without any bubbles.  This kit came with wipes and a cleaning cloth.  It helps to dab the ipad with a piece of masking tape to pick up any remaining dust before the glass goes on.', 'overall': 5.0, 'summary': 'Excellent', 'unixReviewTime': 1399420800, 'reviewTime': '05 7, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c1'), 'reviewerID': 'ADTAGIHSU42HH', 'asin': 'B00E4KP4W6', 'reviewerName': 'Wvmtnivy', 'helpful': [1, 1], 'reviewText': 'Easy application and clear as glass, one step. Received product very promptly with no complications. Very please with my purchase', 'overall': 5.0, 'summary': 'Nice screen protector', 'unixReviewTime': 1385251200, 'reviewTime': '11 24, 2013'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c2'), 'reviewerID': 'A2QXOUHUL5CDT5', 'asin': 'B00E4KP8VI', 'reviewerName': 'Cassi Olsen', 'helpful': [0, 0], 'reviewText': "Bought these even though I was skeptical. They ended up being very awesome. They're somewhat large, so they'll fit big heads or over glasses well. They sound clear, the mic works well and that it's short is a plus. They feel cheap/flimsy at first, but have been holding up well. Definitely would buy again!", 'overall': 5.0, 'summary': 'Great headset for cheap.', 'unixReviewTime': 1379030400, 'reviewTime': '09 13, 2013'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c3'), 'reviewerID': 'A1YQI2Y7DRYFZL', 'asin': 'B00E4KPMC8', 'reviewerName': 'HBP', 'helpful': [1, 1], 'reviewText': "Despite what the specifications say this camera will only tilt about 75 degrees which means it will not look horizontal.  If you have in mind looking out across an open area outdoors be prepared to mount it sky high because it will always look downward.  The camera appears to be a Foscam fi8919w clone.  It looks like and responds to all the same command syntax.The camera works well electronically.  I had no problem using the ActiveX mode in Windows 7 and Internet Explorer 11.  The software that comes with this camera was written for Windows XP and requires some compatibility tinkering to run in Win7.  It wasn't stellar when it was written and now it is years out of date.  On the plus side, the built in wifi works very well as mine is a long way from the AP and works without issue.Like a lot of these cameras it was not focused well from the factory which required me to disassemble the lens cover and twist the focus ring.  In so doing I observed there are no rubber seals or very much weatherproofing at all.  The bracket is nice metal and the electronics seem fine but I suspect I will have water and fogging problems with my outside installation.As the old saying goes, you get what you pay for.  This camera might be a good choice to mount under a porch and watch your front door but in general is not what I would call high quality.", 'overall': 2.0, 'summary': 'Will not tilt horizontal', 'unixReviewTime': 1393459200, 'reviewTime': '02 27, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c4'), 'reviewerID': 'AWFP70TL8BF43', 'asin': 'B00E4KPMC8', 'reviewerName': 'PJ "Peter"', 'helpful': [1, 1], 'reviewText': 'During the day this cam had a decent picture. The wireless seems to work a little better than on other models. My problem was the range of the LED lighting at night. I have a 50 foot driveway and unfortunately this had a ranges of about a third of the distance. This would be a good cam for on a porch to see who is at your door and do well at night.', 'overall': 3.0, 'summary': 'Not what I needed', 'unixReviewTime': 1393027200, 'reviewTime': '02 22, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c5'), 'reviewerID': 'A1T7SJ8JMCIIZ8', 'asin': 'B00E4KPMC8', 'reviewerName': 'Tracey Wesolowski', 'helpful': [1, 1], 'reviewText': 'The EasyN F-series Camera does not support Windows 7 or Windows 8 OS.  Limited to no customer service for support or return purposes.  Unless you speak and/or understand Mandarin or Cantanese, purchase another system.', 'overall': 1.0, 'summary': 'DO NOT PURCHASE!', 'unixReviewTime': 1392595200, 'reviewTime': '02 17, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c6'), 'reviewerID': 'A2QO3GRUYBVDX5', 'asin': 'B00E4KQ5C4', 'reviewerName': 'Alexander Cornwell', 'helpful': [1, 1], 'reviewText': "These may seem like they're gonna be crap for the low price but just hear me out! These sound amazing, the mic records in HD quality for recording, the earphones... are actually noise cancelling! The price is amazing! The fact that it's so low astonishes me! All around, your not making a mistake for buying these!", 'overall': 5.0, 'summary': 'How?', 'unixReviewTime': 1388707200, 'reviewTime': '01 3, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c7'), 'reviewerID': 'AQ1VEA1RAXMJM', 'asin': 'B00E4KQ9GG', 'reviewerName': 'Amazon Customer "Annette"', 'helpful': [1, 1], 'reviewText': 'I wasnt sure at first if I liked it, but after I figured out how to use the stand, I really like it.Pros: a tight fit without those corner elastic bands. Nice and snugHas a nice stand, so you can use it in an upright positionHas protective inside so when you close your case, it doesnt scratch the screencon:  Only one. When you slide the tab into one of the grooves so you can use it in an upright position, it slides out veryEasily. I am hoping that they make that groove a little deeper the next time', 'overall': 4.0, 'summary': 'nice fitting case for the samsung galaxy tab 3', 'unixReviewTime': 1390953600, 'reviewTime': '01 29, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c8'), 'reviewerID': 'A28YUFBI33QZ28', 'asin': 'B00E4KQ9GG', 'reviewerName': 'Amazon Customer', 'helpful': [4, 4], 'reviewText': 'This is a great case. It has a smooth luxurious feel. My 8 inch Samsung tablet fits snugly in the hardshell back. I especially like the clip that locks it closed. Very sturdily built and worth the money. I have always had good service from Speck cases and it looks like this one will be no exception. I would reccomend', 'overall': 5.0, 'summary': 'Top notch case !', 'unixReviewTime': 1385164800, 'reviewTime': '11 23, 2013'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371c9'), 'reviewerID': 'A1EN2PR6V7F87Z', 'asin': 'B00E4KQ9GG', 'reviewerName': 'Anne', 'helpful': [1, 1], 'reviewText': 'Lightweight and thin.  But the tablet does not fit the best at the corners.  If you consistently remove the tablet from its case, corner fit helps in that.  However, the side to side fit is completely secure. When need a replacement,  will likely get this product again.', 'overall': 3.0, 'summary': 'thin but not the best fit', 'unixReviewTime': 1400371200, 'reviewTime': '05 18, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371ca'), 'reviewerID': 'A1Y109DY2NSQYP', 'asin': 'B00E4KQ9GG', 'reviewerName': 'Barry Palacios', 'helpful': [0, 1], 'reviewText': "Ordered this thining it would be a perfect fit being this is speck and all.  Unfortunately it didnt live up to my expectations.  The fit was unacceptable,  there were gaps all over.  Also my other cheap $15 case has the screen sleep and wake up function which the speck doesn't have.  I would have expected more ay this price range.", 'overall': 2.0, 'summary': 'not worth the money!', 'unixReviewTime': 1389571200, 'reviewTime': '01 13, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371cb'), 'reviewerID': 'A1W8TUEAXHF1H9', 'asin': 'B00E4KQ9GG', 'reviewerName': 'Carlos Seer', 'helpful': [1, 1], 'reviewText': 'Recieved exact product as specified, no defects, product recieved within a week. The case is very durable, hold tablet in various positions.  Elegant design with the leather exterior. Top product', 'overall': 5.0, 'summary': 'excelent case', 'unixReviewTime': 1395100800, 'reviewTime': '03 18, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371cc'), 'reviewerID': 'A2U0VQAQHEFB1Y', 'asin': 'B00E4KQ9GG', 'reviewerName': 'DaddyO', 'helpful': [1, 1], 'reviewText': "i chose to buy this case because it cost more and I knew the reputation of Speck as being TOPs, however, the one I bought did not fit properly, perhaps because the Tab3 8&#34; is new they have not perfected its fit.  My tabled kept snapping off.  It felt as if it didn't fit properly. I had to return it.", 'overall': 3.0, 'summary': 'Beautiful design, good quality...but', 'unixReviewTime': 1389139200, 'reviewTime': '01 8, 2014'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371cd'), 'reviewerID': 'A17970XJG2BYIA', 'asin': 'B00E4KQ9GG', 'reviewerName': 'Linzee1998', 'helpful': [1, 2], 'reviewText': 'I was so excited to get this case...too bad it doesnt fit. The top and bottom both have a significant gap between the tab and the case. It ruined my screen protector and is really hard to get in and out.I will be sending it back.', 'overall': 1.0, 'summary': 'Doesnt fit!', 'unixReviewTime': 1387929600, 'reviewTime': '12 25, 2013'}
# {'_id': ObjectId('5e5ca1dfb2b52b52e00371ce'), 'reviewerID': 'A6EAQI9PSIFP5', 'asin': 'B00E4KQ9K2', 'reviewerName': 'Amazon Customer', 'helpful': [0, 0], 'reviewText': 'Very satisfied with it, blue is bright but not over, perfect fit and easy to use..my samsung s4 is much safer now..', 'overall': 5.0, 'summary': 'great', 'unixReviewTime': 1395619200, 'reviewTime': '03 24, 2014'}

# %% [markdown]
# ## Create a SQL database and table to hold each document from “electronics”.

# %%
pw = "" # a dynamic password for users to enter

# %%
# Create eBay Database and eBay_items table.
conn = pymysql.connect(host='localhost', user = 'root', password = pw)
cursor = conn.cursor()

# %%
# Create database amazon_SQL
SQL_DB = "amazon_SQL"
cursor.execute('DROP DATABASE IF EXISTS '+SQL_DB)
query_DB = "CREATE DATABASE IF NOT EXISTS " + SQL_DB + ";"
cursor.execute(query_DB)
# Out:
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1008, "Can't drop database 'amazon_sql'; database doesn't exist")
#   result = self._query(query)
# 1

# %%
# Create an empty table called electronics_SQL.
SQL_table = "electronics_SQL"
cursor.execute('DROP TABLE IF EXISTS ' + SQL_DB + '.' + SQL_table)
query_TB = "CREATE TABLE IF NOT EXISTS " + SQL_DB + "." + SQL_table + "(" \
+ "id VARCHAR(100) NOT NULL PRIMARY KEY" \
+ ", reviewerID VARCHAR(50)" \
+ ", asin VARCHAR(50)" \
+ ", reviewerName VARCHAR(100)" \
+ ", helpful VARCHAR(1000)" \
+ ", overall int(2)" \
+ ", summary VARCHAR(3000)" \
+ ", unixReviewTime int(15)" \
+ ", ReviewTime date" \
+ ");"

cursor.execute(query_TB);
cursor.close()
conn.close()
# Out:
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1681, 'Integer display width is deprecated and will be removed in a future release.')
#   result = self._query(query)

# %% [markdown]
# ### (1) reads all documents from “electronics” in MongoDB

# %%
results = coll.find()
# list to convert the cursor type.
results_list = list(results)

# %%
results_list
# Out:
# [{'_id': ObjectId('5e5ca1dfb2b52b52e00371b6'),
#   'reviewerID': 'AKM1MP6P0OYPR',
#   'asin': '0132793040',
#   'reviewerName': 'Vicki Gibson "momo4"',
#   'helpful': [1, 1],
#   'reviewText': 'Corey Barker does a great job of explaining Blend Modes in this DVD. All of the Kelby training videos are great but pricey to buy individually. If you really want bang for your buck just subscribe to Kelby Training online.',
#   'overall': 5.0,
#   'summary': 'Very thorough',
#   'unixReviewTime': 1365811200,
#   'reviewTime': '04 13, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371b7'),
#   'reviewerID': 'A2X8VX4DPMQFQQ',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'lily68',
#   'helpful': [1, 1],
#   'reviewText': "I can't believe I waited to long to switch to a glass screen protector.  I love this.  It feels and looks like there is no protector on.  It does show fingerprints, which I think is inevitable unless you use a matte finish screen protector, but they wipe right away. I would definitely recommend this! Easier to apply than the films too!",
#   'overall': 5.0,
#   'summary': 'LOVE this screen protector!!',
#   'unixReviewTime': 1393459200,
#   'reviewTime': '02 27, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371b8'),
#   'reviewerID': 'A1JEKX4D58576X',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'Mara Milagros',
#   'helpful': [2, 2],
#   'reviewText': 'presentation of product is beautiful, everything is perfect! And my iPad screen seems to be really protected. I recommend it.',
#   'overall': 5.0,
#   'summary': 'excellent',
#   'unixReviewTime': 1394496000,
#   'reviewTime': '03 11, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371b9'),
#   'reviewerID': 'ATM6RRB90D8DV',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'Matthew D. Irmen "Jazz Fan"',
#   'helpful': [1, 2],
#   'reviewText': "I bought this screen protector because I was unimpressed with the Otterbox Defender attached screen protector. If I have a retina display iPad, I want it to look like it has retina display, not a hazy iPad 2. So... I started researching and came across this tempered glass screen protector with promises of easy installation and beautiful retina quality display. I have to admit that I am very impressed with the picture quality and the ease of installation. Best of all, I was able to tear out the plastic screen protector from my Otterbox defender case and use the case without issue. So why did I give it 4 stars? Because of the home button sticker! The sticker is a lame plastic blob that sits on the home button and looks ugly. I thought little of it because I would bury it under the frame of the Otterbox case. Unfortunately it causes slight problems with the use of the home button. If I press for slightly too long (a second) it activates siri. Believe me it's not the end of the world and I love how the screen looks it's just a minor issue that justifies 4 stars.",
#   'overall': 4.0,
#   'summary': 'Nice looking, easy to install glass screen protector that works beautifully with the Otterbox Defender.',
#   'unixReviewTime': 1393891200,
#   'reviewTime': '03 4, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371ba'),
#   'reviewerID': 'A3QOYJ97A6OMX7',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'pharmdaddyd',
#   'helpful': [1, 1],
#   'reviewText': 'this is a great screen protector for the price, not as expensive as others and just as good as name brands',
#   'overall': 5.0,
#   'summary': 'great for the price',
#   'unixReviewTime': 1388361600,
#   'reviewTime': '12 30, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371bb'),
#   'reviewerID': 'AWO84NZ6VDYR2',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'shalane rogillio',
#   'helpful': [0, 0],
#   'reviewText': 'I ordered two of these &#34;shatter proof&#34; protector for iPad s.  One arrived broken. Amazon refunded and ordered another one just like it.  Using the flat plastic tool to push bubbles out, the edge of this chipped.  This is definitely not up breakable and when it does break it is in big shards.  So from the 3 I have touched, only one is perfect.',
#   'overall': 1.0,
#   'summary': 'Not happy with this, would not recommend',
#   'unixReviewTime': 1404777600,
#   'reviewTime': '07 8, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371bc'),
#   'reviewerID': 'A15ZEBTKX72NPB',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'S. Marcus "pdtpoet"',
#   'helpful': [1, 2],
#   'reviewText': "For some reasons, the clear film screens that other people like have short lives on my devices...they begin to curl or bubble or peel within a week or 2 of application, and look terrible.  The only film screen that stayed on my ipad blurred my view of the screen a little bit, which was a constant annoyance.  Putting a tempered glass screen on my iphone 5 solved all those problems so well that I replaced the plastic screen on my iPad 2 with this WOPUTUO tempered glass screen protector.  Application was easy and there were no bubbles in the viewing area at all!  The screen is wonderfully clear so I can finally see the full resolution of the iPad screen.  I'm only sorry I did not use the tempered glass screen when I first bought my iPad!",
#   'overall': 5.0,
#   'summary': 'Far better than film screens for iPhone or iPad!',
#   'unixReviewTime': 1392249600,
#   'reviewTime': '02 13, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371bd'),
#   'reviewerID': 'A2ZI014DO0LWEW',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'SueinCa',
#   'helpful': [0, 0],
#   'reviewText': 'This was just what the doctor ordered for my broken screen and i could not afford replacement and this is next best thing and perfect.',
#   'overall': 5.0,
#   'summary': 'Right On',
#   'unixReviewTime': 1397174400,
#   'reviewTime': '04 11, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371be'),
#   'reviewerID': 'A3IN9CE5GG8VKR',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'Tess Brown',
#   'helpful': [0, 0],
#   'reviewText': 'This is the best screen protector.  Very smooth feel! Looks incredible. Takes a little skill to put on but no air bubbles at all!',
#   'overall': 5.0,
#   'summary': 'Tempered Glass Screen Protector',
#   'unixReviewTime': 1399593600,
#   'reviewTime': '05 9, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371bf'),
#   'reviewerID': 'A1U9ZR7HQ5EZ6L',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'Thinker623',
#   'helpful': [1, 1],
#   'reviewText': 'Great glass cover for IPad.  I had been using ones that are top screen protector made of plastic.  I dropped my IpadAnd had a dent in protector.  I heard about these tempered glass protectors from my son.  They priced at $60.  This one was much cheaper and works great.  Cannot believe the quality difference between glass and the plastic.',
#   'overall': 5.0,
#   'summary': 'Great glass cover for IPad.',
#   'unixReviewTime': 1391126400,
#   'reviewTime': '01 31, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c0'),
#   'reviewerID': 'A2DFGG75NH91H2',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'Thuddds',
#   'helpful': [0, 0],
#   'reviewText': 'Glass screen protectors are a drastic improvement over plastic film protectors.  The glass fits perfectly without any bubbles.  This kit came with wipes and a cleaning cloth.  It helps to dab the ipad with a piece of masking tape to pick up any remaining dust before the glass goes on.',
#   'overall': 5.0,
#   'summary': 'Excellent',
#   'unixReviewTime': 1399420800,
#   'reviewTime': '05 7, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c1'),
#   'reviewerID': 'ADTAGIHSU42HH',
#   'asin': 'B00E4KP4W6',
#   'reviewerName': 'Wvmtnivy',
#   'helpful': [1, 1],
#   'reviewText': 'Easy application and clear as glass, one step. Received product very promptly with no complications. Very please with my purchase',
#   'overall': 5.0,
#   'summary': 'Nice screen protector',
#   'unixReviewTime': 1385251200,
#   'reviewTime': '11 24, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c2'),
#   'reviewerID': 'A2QXOUHUL5CDT5',
#   'asin': 'B00E4KP8VI',
#   'reviewerName': 'Cassi Olsen',
#   'helpful': [0, 0],
#   'reviewText': "Bought these even though I was skeptical. They ended up being very awesome. They're somewhat large, so they'll fit big heads or over glasses well. They sound clear, the mic works well and that it's short is a plus. They feel cheap/flimsy at first, but have been holding up well. Definitely would buy again!",
#   'overall': 5.0,
#   'summary': 'Great headset for cheap.',
#   'unixReviewTime': 1379030400,
#   'reviewTime': '09 13, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c3'),
#   'reviewerID': 'A1YQI2Y7DRYFZL',
#   'asin': 'B00E4KPMC8',
#   'reviewerName': 'HBP',
#   'helpful': [1, 1],
#   'reviewText': "Despite what the specifications say this camera will only tilt about 75 degrees which means it will not look horizontal.  If you have in mind looking out across an open area outdoors be prepared to mount it sky high because it will always look downward.  The camera appears to be a Foscam fi8919w clone.  It looks like and responds to all the same command syntax.The camera works well electronically.  I had no problem using the ActiveX mode in Windows 7 and Internet Explorer 11.  The software that comes with this camera was written for Windows XP and requires some compatibility tinkering to run in Win7.  It wasn't stellar when it was written and now it is years out of date.  On the plus side, the built in wifi works very well as mine is a long way from the AP and works without issue.Like a lot of these cameras it was not focused well from the factory which required me to disassemble the lens cover and twist the focus ring.  In so doing I observed there are no rubber seals or very much weatherproofing at all.  The bracket is nice metal and the electronics seem fine but I suspect I will have water and fogging problems with my outside installation.As the old saying goes, you get what you pay for.  This camera might be a good choice to mount under a porch and watch your front door but in general is not what I would call high quality.",
#   'overall': 2.0,
#   'summary': 'Will not tilt horizontal',
#   'unixReviewTime': 1393459200,
#   'reviewTime': '02 27, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c4'),
#   'reviewerID': 'AWFP70TL8BF43',
#   'asin': 'B00E4KPMC8',
#   'reviewerName': 'PJ "Peter"',
#   'helpful': [1, 1],
#   'reviewText': 'During the day this cam had a decent picture. The wireless seems to work a little better than on other models. My problem was the range of the LED lighting at night. I have a 50 foot driveway and unfortunately this had a ranges of about a third of the distance. This would be a good cam for on a porch to see who is at your door and do well at night.',
#   'overall': 3.0,
#   'summary': 'Not what I needed',
#   'unixReviewTime': 1393027200,
#   'reviewTime': '02 22, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c5'),
#   'reviewerID': 'A1T7SJ8JMCIIZ8',
#   'asin': 'B00E4KPMC8',
#   'reviewerName': 'Tracey Wesolowski',
#   'helpful': [1, 1],
#   'reviewText': 'The EasyN F-series Camera does not support Windows 7 or Windows 8 OS.  Limited to no customer service for support or return purposes.  Unless you speak and/or understand Mandarin or Cantanese, purchase another system.',
#   'overall': 1.0,
#   'summary': 'DO NOT PURCHASE!',
#   'unixReviewTime': 1392595200,
#   'reviewTime': '02 17, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c6'),
#   'reviewerID': 'A2QO3GRUYBVDX5',
#   'asin': 'B00E4KQ5C4',
#   'reviewerName': 'Alexander Cornwell',
#   'helpful': [1, 1],
#   'reviewText': "These may seem like they're gonna be crap for the low price but just hear me out! These sound amazing, the mic records in HD quality for recording, the earphones... are actually noise cancelling! The price is amazing! The fact that it's so low astonishes me! All around, your not making a mistake for buying these!",
#   'overall': 5.0,
#   'summary': 'How?',
#   'unixReviewTime': 1388707200,
#   'reviewTime': '01 3, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c7'),
#   'reviewerID': 'AQ1VEA1RAXMJM',
#   'asin': 'B00E4KQ9GG',
#   'reviewerName': 'Amazon Customer "Annette"',
#   'helpful': [1, 1],
#   'reviewText': 'I wasnt sure at first if I liked it, but after I figured out how to use the stand, I really like it.Pros: a tight fit without those corner elastic bands. Nice and snugHas a nice stand, so you can use it in an upright positionHas protective inside so when you close your case, it doesnt scratch the screencon:  Only one. When you slide the tab into one of the grooves so you can use it in an upright position, it slides out veryEasily. I am hoping that they make that groove a little deeper the next time',
#   'overall': 4.0,
#   'summary': 'nice fitting case for the samsung galaxy tab 3',
#   'unixReviewTime': 1390953600,
#   'reviewTime': '01 29, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c8'),
#   'reviewerID': 'A28YUFBI33QZ28',
#   'asin': 'B00E4KQ9GG',
#   'reviewerName': 'Amazon Customer',
#   'helpful': [4, 4],
#   'reviewText': 'This is a great case. It has a smooth luxurious feel. My 8 inch Samsung tablet fits snugly in the hardshell back. I especially like the clip that locks it closed. Very sturdily built and worth the money. I have always had good service from Speck cases and it looks like this one will be no exception. I would reccomend',
#   'overall': 5.0,
#   'summary': 'Top notch case !',
#   'unixReviewTime': 1385164800,
#   'reviewTime': '11 23, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371c9'),
#   'reviewerID': 'A1EN2PR6V7F87Z',
#   'asin': 'B00E4KQ9GG',
#   'reviewerName': 'Anne',
#   'helpful': [1, 1],
#   'reviewText': 'Lightweight and thin.  But the tablet does not fit the best at the corners.  If you consistently remove the tablet from its case, corner fit helps in that.  However, the side to side fit is completely secure. When need a replacement,  will likely get this product again.',
#   'overall': 3.0,
#   'summary': 'thin but not the best fit',
#   'unixReviewTime': 1400371200,
#   'reviewTime': '05 18, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371ca'),
#   'reviewerID': 'A1Y109DY2NSQYP',
#   'asin': 'B00E4KQ9GG',
#   'reviewerName': 'Barry Palacios',
#   'helpful': [0, 1],
#   'reviewText': "Ordered this thining it would be a perfect fit being this is speck and all.  Unfortunately it didnt live up to my expectations.  The fit was unacceptable,  there were gaps all over.  Also my other cheap $15 case has the screen sleep and wake up function which the speck doesn't have.  I would have expected more ay this price range.",
#   'overall': 2.0,
#   'summary': 'not worth the money!',
#   'unixReviewTime': 1389571200,
#   'reviewTime': '01 13, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371cb'),
#   'reviewerID': 'A1W8TUEAXHF1H9',
#   'asin': 'B00E4KQ9GG',
#   'reviewerName': 'Carlos Seer',
#   'helpful': [1, 1],
#   'reviewText': 'Recieved exact product as specified, no defects, product recieved within a week. The case is very durable, hold tablet in various positions.  Elegant design with the leather exterior. Top product',
#   'overall': 5.0,
#   'summary': 'excelent case',
#   'unixReviewTime': 1395100800,
#   'reviewTime': '03 18, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371cc'),
#   'reviewerID': 'A2U0VQAQHEFB1Y',
#   'asin': 'B00E4KQ9GG',
#   'reviewerName': 'DaddyO',
#   'helpful': [1, 1],
#   'reviewText': "i chose to buy this case because it cost more and I knew the reputation of Speck as being TOPs, however, the one I bought did not fit properly, perhaps because the Tab3 8&#34; is new they have not perfected its fit.  My tabled kept snapping off.  It felt as if it didn't fit properly. I had to return it.",
#   'overall': 3.0,
#   'summary': 'Beautiful design, good quality...but',
#   'unixReviewTime': 1389139200,
#   'reviewTime': '01 8, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371cd'),
#   'reviewerID': 'A17970XJG2BYIA',
#   'asin': 'B00E4KQ9GG',
#   'reviewerName': 'Linzee1998',
#   'helpful': [1, 2],
#   'reviewText': 'I was so excited to get this case...too bad it doesnt fit. The top and bottom both have a significant gap between the tab and the case. It ruined my screen protector and is really hard to get in and out.I will be sending it back.',
#   'overall': 1.0,
#   'summary': 'Doesnt fit!',
#   'unixReviewTime': 1387929600,
#   'reviewTime': '12 25, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371ce'),
#   'reviewerID': 'A6EAQI9PSIFP5',
#   'asin': 'B00E4KQ9K2',
#   'reviewerName': 'Amazon Customer',
#   'helpful': [0, 0],
#   'reviewText': 'Very satisfied with it, blue is bright but not over, perfect fit and easy to use..my samsung s4 is much safer now..',
#   'overall': 5.0,
#   'summary': 'great',
#   'unixReviewTime': 1395619200,
#   'reviewTime': '03 24, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371cf'),
#   'reviewerID': 'A1D6ESQ8B33IE3',
#   'asin': 'B00E4KQ9K2',
#   'reviewerName': 'Joyce Ann, Maryland',
#   'helpful': [0, 0],
#   'reviewText': "I am extremely pleased with my Speck case. I have a few Speck products and, in my humble opinion, they are the best. As for this case, everything works well, all the cut-outs are perfect for my Tab 3 and it's extremely sturdy and protective without being heavy. If they had it in other colors such as red and white, I'd purchase them as well. You can't go wrong with this case or Speck.",
#   'overall': 5.0,
#   'summary': 'Another Great Speck Product',
#   'unixReviewTime': 1404777600,
#   'reviewTime': '07 8, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d0'),
#   'reviewerID': 'A1DQMWBMWJSUU',
#   'asin': 'B00E4KQ9K2',
#   'reviewerName': 'Kevin Weringer',
#   'helpful': [2, 2],
#   'reviewText': 'Works as described. I really like the latch to keep Case closed when not in use or when case is flipped around while in use.',
#   'overall': 5.0,
#   'summary': 'Best Case for the money!',
#   'unixReviewTime': 1389657600,
#   'reviewTime': '01 14, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d1'),
#   'reviewerID': 'A2ID95UJ43XY5Q',
#   'asin': 'B00E4KQ9K2',
#   'reviewerName': 'Maria S',
#   'helpful': [1, 1],
#   'reviewText': "Is not an otter box, but it does the job for me.I like that the screen cover is attached so I don't loose it.Doesn't add bulk. Sturdy.Ease to install and use.Will protect form minor to moderate falls, I doubt it will for major ones.But then that's what the otterbox is for.",
#   'overall': 5.0,
#   'summary': 'Is not an otter box, but it does the job for me.',
#   'unixReviewTime': 1389744000,
#   'reviewTime': '01 15, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d2'),
#   'reviewerID': 'ANO3QTN6M8MV8',
#   'asin': 'B00E4KQ9K2',
#   'reviewerName': 'Mountaineer',
#   'helpful': [0, 0],
#   'reviewText': 'Great fit and quality. Keeps your Galaxy 3 Tab safe for traveling without being bulky. I also bought one for my Ipad. Would highly recommend this product.',
#   'overall': 5.0,
#   'summary': 'Awesome fit.',
#   'unixReviewTime': 1397520000,
#   'reviewTime': '04 15, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d3'),
#   'reviewerID': 'A17E6TO7VQ0SMW',
#   'asin': 'B00E4KQ9K2',
#   'reviewerName': 'Stacie Haislop',
#   'helpful': [1, 1],
#   'reviewText': 'I bought this for my sons tablet for Christmas. He is 10, so I was scared he may drop the tablet and break it. He has actually dropped the tablet in the kitchen with this case on it and not one problem with the tablet. Great craftsmanship. I am very pleased!',
#   'overall': 5.0,
#   'summary': 'Wonderful product',
#   'unixReviewTime': 1393027200,
#   'reviewTime': '02 22, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d4'),
#   'reviewerID': 'AMFL9ITY59PBV',
#   'asin': 'B00E4KQ9K2',
#   'reviewerName': 'TY',
#   'helpful': [2, 2],
#   'reviewText': 'Solid case, not flimsy, and looks great. Compacted, not bulky.  It can easily be placed in your purse or briefcase. My child dropped it a couple of time, and nothing happened to her tablet.',
#   'overall': 5.0,
#   'summary': 'Great Product',
#   'unixReviewTime': 1389398400,
#   'reviewTime': '01 11, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d5'),
#   'reviewerID': 'AXFNL92ESR7KX',
#   'asin': 'B00E4KQD4E',
#   'reviewerName': 'sue',
#   'helpful': [0, 0],
#   'reviewText': 'This screen protector is very durable. I have had the same protector on for a couple months and do not have any scratches on it yet. I use my Galaxy Tab everyday.',
#   'overall': 4.0,
#   'summary': 'screen protector',
#   'unixReviewTime': 1397692800,
#   'reviewTime': '04 17, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d6'),
#   'reviewerID': 'A34S2PBK82BCBY',
#   'asin': 'B00E4KZBX8',
#   'reviewerName': 'Angel Dean',
#   'helpful': [1, 1],
#   'reviewText': "I use a lot of devices that need serial ports and most newer computers do not have them.  This card fits the bill nicely.  My gateway desktop has a low profile case and it works very well.Pros: No jumper settings. (All settings in driver software), Cost, Low profile, Adjustable voltage if needed. Stopped problem of RF getting back into USB to Serial converter.Cons: On a low profile case it uses 2 slots if you use both serial ports. Windows does not detect and install drivers automatically.I would recommend a buy on this one if you need serial ports and don't mind software settings.",
#   'overall': 4.0,
#   'summary': 'Solves a problem with newer computers',
#   'unixReviewTime': 1394323200,
#   'reviewTime': '03 9, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d7'),
#   'reviewerID': 'A2YW2DVVYTZV2U',
#   'asin': 'B00E4KZDJ0',
#   'reviewerName': 'Palani',
#   'helpful': [0, 0],
#   'reviewText': "Recently I upgraded my old Dell Vostro 200 from XP to Windows 8.1. Just checking out Windows 8.1 to see if I would like it. I read and heard a lot of negatives about 8.1. When I upgraded the on-board Ethernet Connection would not stay active and it had to be made active every time I would start the computer. I decided to replace it. Star Tech Products are very reliable! I have purchased several products from Star Tech and was always satisfied. This Ethernet Card was a little more expensive then several others I considered but, I felt as if it would perform better. I installed it in the old Dell Vostro and Windows 8.1 found it with no problems. Didn't have to load the drivers that came with the Ethernet Card. It starts every time no problems! I highly recommend this NIC Server Adapter. Oh Yeah, Windows 8.1 isn't as bad as I thought!!!",
#   'overall': 5.0,
#   'summary': 'Nice Ethernet Card',
#   'unixReviewTime': 1399334400,
#   'reviewTime': '05 6, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d8'),
#   'reviewerID': 'A3BJC1Y9VA5JLW',
#   'asin': 'B00E4L35DA',
#   'helpful': [0, 0],
#   'reviewText': 'Have this mounted to some rails on my M70 N-PAP AK-47. It makes it much more comfortable to handle than flat on the rails or grabbing up on the wobbly magazine. This grip is well worth the money.  Even comes with a replacement piece for the finger gap thing.  You can remove it and put in a flush piece that removes that finger gap (not sure the technical name of it)',
#   'overall': 5.0,
#   'summary': 'Great value! On my M70/N-PAP AK-47',
#   'unixReviewTime': 1386115200,
#   'reviewTime': '12 4, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371d9'),
#   'reviewerID': 'A106MIC3TTLQOY',
#   'asin': 'B00E4L35DA',
#   'reviewerName': 'Amazon Customer',
#   'helpful': [2, 4],
#   'reviewText': 'Great small profile camera. Clear image for the price. Compares to cameras I have that cost many times more.Would recommend especially for daytime use. Night-time is acceptable but, not as clear as daytime.',
#   'overall': 5.0,
#   'summary': 'Great camera',
#   'unixReviewTime': 1390003200,
#   'reviewTime': '01 18, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371da'),
#   'reviewerID': 'A37I3SRFD7Z8UH',
#   'asin': 'B00E4L35DA',
#   'reviewerName': 'D. Darby',
#   'helpful': [5, 6],
#   'reviewText': "The description (nor the comments - dammit!!!) failed to mention this camera is Black and White only.  I'm returning it.",
#   'overall': 1.0,
#   'summary': 'Buyer beware.  NOT color',
#   'unixReviewTime': 1396742400,
#   'reviewTime': '04 6, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371db'),
#   'reviewerID': 'A2QR5IG5CSXO4S',
#   'asin': 'B00E4L35DA',
#   'reviewerName': 'Steven Ligon',
#   'helpful': [1, 2],
#   'reviewText': 'I originally wanted this to put out back to watch the dog while shes out there, yard is fenced in but that doesnt stop her if shes bored enough or tried to come in the front door lolVery nice picture and ez setup to my tvwill be buying another soon for the front door!The night vison is excellent in pitch black up to 30ft or so, low profile as well',
#   'overall': 5.0,
#   'summary': 'Amazing cam for the price!',
#   'unixReviewTime': 1394496000,
#   'reviewTime': '03 11, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371dc'),
#   'reviewerID': 'A2RN76Q3R292VE',
#   'asin': 'B00E4L3N9Q',
#   'reviewerName': 'JC',
#   'helpful': [0, 0],
#   'reviewText': 'Battery does hold charge properly and it even comes with an external meter letting you know how much charge the battery is holding without turning the laptop on.',
#   'overall': 4.0,
#   'summary': 'Great replacement for your original equipment at less than half the price.',
#   'unixReviewTime': 1395014400,
#   'reviewTime': '03 17, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371dd'),
#   'reviewerID': 'A2LJUSIVFXY6QU',
#   'asin': 'B00E4L48EA',
#   'reviewerName': 'Pooh Kong',
#   'helpful': [0, 0],
#   'reviewText': 'This fits perfect for my galaxy tab 3 and protects it very well and neat design. I Would recommend it!',
#   'overall': 5.0,
#   'summary': 'perfect!',
#   'unixReviewTime': 1387238400,
#   'reviewTime': '12 17, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371de'),
#   'reviewerID': 'A1FDT5RW9DSM5W',
#   'asin': 'B00E4L7FLI',
#   'reviewerName': 'michael r chapel',
#   'helpful': [0, 0],
#   'reviewText': 'MY battery was no better than the four year old one i had. it failed completely in 4 months and i only use computer monthly. I sent it back its been over a month now my old battery has failed and i have no computer at all. sitting in library typing this they do not answer no calls or letters neither',
#   'overall': 1.0,
#   'summary': 'dont buy from them.',
#   'unixReviewTime': 1402012800,
#   'reviewTime': '06 6, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371df'),
#   'reviewerID': 'A3DT0KN789A643',
#   'asin': 'B00E4L7TS2',
#   'reviewerName': 'frodo6211',
#   'helpful': [0, 0],
#   'reviewText': "Haven't had the battery long enough to give an in depth review. I purchased this battery for my son's laptop and did so because the warranty was twice as long as any other comparable battery being sold.",
#   'overall': 4.0,
#   'summary': 'Two year warranty sold me!',
#   'unixReviewTime': 1401753600,
#   'reviewTime': '06 3, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e0'),
#   'reviewerID': 'A35YQZBSPLFH07',
#   'asin': 'B00E4LAL82',
#   'reviewerName': 'Alex B.',
#   'helpful': [2, 2],
#   'reviewText': 'The idea is awesome.The case is waaaaaaay to expensive for some cheap elastic and a non rubber coated bumper (its just a hard plastic non protective bumper).The idea is for you to be able to slip all kinds of normally wallet carried goodies, like credit cards, money, business cards, IDs etc. Into the elastic on the back of the tablet. Like I said at the beginning, the idea is awesome.However, the elastic bands are so close together, it is difficult to get things inserted, and even more trouble to get an item out, like an Id card or credit card, unless you very carefully potion each item when you insert it, you wind up needing to remove multiple items to use just one.What is does do well is give you a new way to nhold your tablet. You can slip tour hand into the straps from any angle making it easy to hold and use.',
#   'overall': 3.0,
#   'summary': 'good idea, not so easy to use',
#   'unixReviewTime': 1393718400,
#   'reviewTime': '03 2, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e1'),
#   'reviewerID': 'AYH19ERSIKCFS',
#   'asin': 'B00E4LBZZK',
#   'reviewerName': 'Angie',
#   'helpful': [0, 0],
#   'reviewText': 'This laser replaced my original from my PS3 slim.Fairly easy installation, there are plenty of videos on YouTube to help.My PS3 is working just like it was brand new.The included T8 torx security screwdriver is a great bonus, as they are typically around $8, & usually not carried in local hardware stores.Highly recommend this product.Came packaged well, & fast delivery.',
#   'overall': 5.0,
#   'summary': 'Perfect. Works like a charm',
#   'unixReviewTime': 1393113600,
#   'reviewTime': '02 23, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e2'),
#   'reviewerID': 'A2G24L6809X08B',
#   'asin': 'B00E4LBZZK',
#   'reviewerName': 'Dribear',
#   'helpful': [0, 0],
#   'reviewText': 'The day after Xmas, my PS3 stops reading discs. Happy Xmas to me! Not. Anyways, searched for a bit to find an inexpensive repair. This was it. Looked up the instructions on youtube and fired away. For the less tech-inclined, I recommend purchasing the whole drive to swap. Will buy again if necessary. This is the real deal. Make sure you search and make sure this is the correct laser you need.',
#   'overall': 5.0,
#   'summary': 'Totally worth it.',
#   'unixReviewTime': 1395187200,
#   'reviewTime': '03 19, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e3'),
#   'reviewerID': 'ABUQTBTB7HDRK',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'a. fraser',
#   'helpful': [0, 0],
#   'reviewText': "Very great quality case one of the best for young children! Other ones my 2 and 3 year old can get off easy this one gives them a hard time and that's what I was looking for plus it gives the protection I want!!",
#   'overall': 5.0,
#   'summary': 'Dutiable even for a 2 and 3 year old love it!',
#   'unixReviewTime': 1393718400,
#   'reviewTime': '03 2, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e4'),
#   'reviewerID': 'ACQLVZCIPSA2Q',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'alexis anderson',
#   'helpful': [0, 0],
#   'reviewText': "I bought the Pandamimi ULAK Hybrid Hard Colorful Bubble Pattern with SIlicon Case Cover for Apple iPod Touch (Generation 5) + Screen Protector (cleaning cloth with ULAK Logo) (Bubble Skin/Pink) on Septemeber 3rd 2013 and was supposed to received my between the 9th and the 12th of September. BUUUUUUUUTTTTTTTTT I got it that Saturday!!! I love it, it's perfect, pretty, screen protector ir terrific!! It's one of the really good screen protectors that you can't even tell are on the gadget. I am highly satisfied and thannkful. Ordering from here/this person is a wonderful idea!! A+++++",
#   'overall': 5.0,
#   'summary': 'EARLY!!!',
#   'unixReviewTime': 1378598400,
#   'reviewTime': '09 8, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e5'),
#   'reviewerID': 'A2KZ8V4387ENNE',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'charlene Hickmott',
#   'helpful': [0, 0],
#   'reviewText': 'Just what I wanted. Although it is peeling paint on the side, I love it. I have had it 6 weeks. I am very happy with it.',
#   'overall': 4.0,
#   'summary': 'Love it even tho paint is peeling',
#   'unixReviewTime': 1405468800,
#   'reviewTime': '07 16, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e6'),
#   'reviewerID': 'A27F59IFZG433I',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'Chereese',
#   'helpful': [0, 0],
#   'reviewText': 'MY daughter love her case, it very girly and not to childish. She was able put on the case without any help.',
#   'overall': 5.0,
#   'summary': 'Cute and easy to handle',
#   'unixReviewTime': 1389657600,
#   'reviewTime': '01 14, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e7'),
#   'reviewerID': 'AOV97XL6NZFOA',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'Dawn Foster',
#   'helpful': [0, 0],
#   'reviewText': 'This was bought for my IPod.  I really liked it and I would recommend it for anyone that is thinking about purchasing one',
#   'overall': 5.0,
#   'summary': 'Gift',
#   'unixReviewTime': 1389657600,
#   'reviewTime': '01 14, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e8'),
#   'reviewerID': 'A28KQRIVCUBHP8',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'Dottie Riggs',
#   'helpful': [1, 1],
#   'reviewText': "I got as a stocking stuffer but was not able to use because the case would not close all the way.  The case &#34;snaps&#34; on all sides but one.  I am in the process of &#34;trying&#34; to return for another or a refund. I have not been given the option for exchange only an offer for a 50% refund.  I do not agree with the offer I feel I should be able to get a full refund and be able to send case back at there expense.  I is a cute case but beware before you buy!  If it is defective they don't want to give refund.",
#   'overall': 2.0,
#   'summary': 'cute case but was damaged.',
#   'unixReviewTime': 1388361600,
#   'reviewTime': '12 30, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371e9'),
#   'reviewerID': 'A3LI8WFLMMP2EM',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'I loved it',
#   'helpful': [0, 0],
#   'reviewText': "I would recommend this to people that need this protected case. I've dropped it many of times and still not one scratch.",
#   'overall': 5.0,
#   'summary': 'awesome',
#   'unixReviewTime': 1392940800,
#   'reviewTime': '02 21, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371ea'),
#   'reviewerID': 'AFHIXY0JJZT32',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'Judy',
#   'helpful': [0, 1],
#   'reviewText': "I ordered this case for my granddaughter.  I ordered it on Wednesday evening and it was delivered on Saturday, well before the promised delivery date.  I haven't seen it in use yet because it is part of her birthday present and I haven't given it to her yet.",
#   'overall': 5.0,
#   'summary': 'Case for ipod',
#   'unixReviewTime': 1380499200,
#   'reviewTime': '09 30, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371eb'),
#   'reviewerID': 'A3BIOYNLX5I4H4',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'Kerri Peterson',
#   'helpful': [0, 0],
#   'reviewText': "This case cracked after 3 weeks. It was only $8 so didn't expect much. It was cheap and obviously didn't hold up",
#   'overall': 1.0,
#   'summary': 'Cheap case',
#   'unixReviewTime': 1389744000,
#   'reviewTime': '01 15, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371ec'),
#   'reviewerID': 'A3UTRYPOY0PCMG',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'Maria Lyons',
#   'helpful': [0, 0],
#   'reviewText': 'This is my daughters favorite case. All her friends love it. It is very durable. So you get a great looking case that also protects your iPod.',
#   'overall': 5.0,
#   'summary': 'love it',
#   'unixReviewTime': 1382572800,
#   'reviewTime': '10 24, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371ed'),
#   'reviewerID': 'A3V7G45M4OO78E',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'taracam81',
#   'helpful': [0, 0],
#   'reviewText': 'got this for my daughter as a Christmas gift and she loves it. price was good so i would buy again.',
#   'overall': 5.0,
#   'summary': 'great',
#   'unixReviewTime': 1388102400,
#   'reviewTime': '12 27, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371ee'),
#   'reviewerID': 'AXVKMYWNIHK7W',
#   'asin': 'B00E4LF2Z4',
#   'reviewerName': 'Terri "3kids-at-home"',
#   'helpful': [0, 0],
#   'reviewText': "I ordered this case for my daughter, and it is adorable. I got the bubble pattern since she's into polka dots and and all things pink. I like that it's rubberized for shock protection in case she drops it. Comes with cleaning cloth, and plastic cover so the front won't get scratched while playing. So far, so good. Still fits nicely in her pocket, great buy.",
#   'overall': 5.0,
#   'summary': 'Bubble Pattern ipod case',
#   'unixReviewTime': 1381449600,
#   'reviewTime': '10 11, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371ef'),
#   'reviewerID': 'A3FU7SZ4P58W06',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': 'DarienX',
#   'helpful': [0, 0],
#   'reviewText': "I bought it first thinking it was the one color 5500k model, so I could had a powerfull 600 leds, but instead, i received the bi-color model, 300 leds 5500k and 300 with 3200k. I also tought it includes the power suply, but it didn't, i will have to buy elsewhere.Another thing it doesn't say, it uses 2 batteries to light 150 leds each, meaning, if you only use one battery it will use, depending if you put in slot A will be the 5500k and in slot B will use the 3200K ledsBeside those things, the light is good and versatil with his remote control.",
#   'overall': 4.0,
#   'summary': 'Great Light but little information',
#   'unixReviewTime': 1400112000,
#   'reviewTime': '05 15, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f0'),
#   'reviewerID': 'AIM4GJ54RUZP0',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': 'iDex Media',
#   'helpful': [0, 0],
#   'reviewText': "My first big concern was te fan noise. What noise? It's pretty dang low and doesn't stay on forever. Additionally, it only kicks on if the light has been on for a while. I used this to light a stage (think about that!) for a 2-hour 4-night event  No problems. For typical shoots where we are running the camera for a shorter period of time I usually don't ever hear the fan kick on because I cut it off between takes... Not because of the noise, really just to conserve power. I've got ONLY GOOD to say. I need more! LOVE the digital dial. LOVE the barndoors. YN hasn't failed me in any of their lighting products!",
#   'overall': 5.0,
#   'summary': 'I need more of this!',
#   'unixReviewTime': 1401321600,
#   'reviewTime': '05 29, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f1'),
#   'reviewerID': 'A1XMJNT4N92R58',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': 'joe',
#   'helpful': [0, 0],
#   'reviewText': 'good product,  was surprised that it did not come with a power cord..',
#   'overall': 4.0,
#   'summary': 'good product, was surprised that it did not come ...',
#   'unixReviewTime': 1405036800,
#   'reviewTime': '07 11, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f2'),
#   'reviewerID': 'ATSS4GTHBVCZZ',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': 'Marcel T. Cabrera Jr.',
#   'helpful': [3, 4],
#   'reviewText': 'Awesome light.  VERY BRIGHT and has a lot of power.Works flawlessly with batteries.However, DOES NOT work with AC Power Adapter?  When you press the Power button, the back LED panel will flicker for 1 second.  And this only flickers sometimes.  Most of the time, you press the power button and there is no response.  :(replacement?',
#   'overall': 3.0,
#   'summary': "Works perfect with Batteries.  Doesn't turn on with AC Adapter?",
#   'unixReviewTime': 1381276800,
#   'reviewTime': '10 9, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f3'),
#   'reviewerID': 'A1WF4QNIE2Z3I7',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': "N's Gadget Reviews",
#   'helpful': [8, 8],
#   'reviewText': "The YN600 is about twice as bright as the YN300 as you might imagine. I believe it's exactly twice as bright just based on my visual assessment. This is VERY bright and with proper bouncing or diffusing can function as a good key light. That's based on my amateur opinion of course.The YN600 doesn't come with a case or bag like the 300, which is a bummer. It only comes with a clear and amber gel but the diffuser clear gel is really more of a protective gel than anything. It doesn't really diffuse anything (same story on the 300) and the light meter on my camera detects only a very minor change in light if any at all when using it. The AMBER is useful though, I like to bounce it off a reflector or through something to create a nice warm light on a subjects face. Your mileage may vary but it's fun to play with.The Yn600 I received DID come with an AC adapter. It works great (previous reviewer should get theirs replaced). It also works great with adapters and it can be controlled via remote either with the same one as the Yn300s or you can actually assign it a channel of its own if you want to control it independently.The remote is a bit nutty as it's the same as the YN600 that has two color temps. So, ya know, deal with it I guess?The things to know about the YN600 are:- 1/4&#34; thread on bottom of light NO HOTSHOE. So if you want to use this with a light stand, you can get adapters to make it happen, but just know that it doesn't use a hotshoe, it uses a 1/4&#34; thread. Unlike the YN300s which have the hotshoe adapter as their primary mounting option. This makes sense, given the 600s size, but it's something to be aware of.- There IS a fan on the backside that turns on when the light is very hot. The fan is NOT silent, but it is not loud either. It is easily worked around with intelligent mic use or you can probably edit it out in post if you hear it at all. It's quieter than a quiet computer but ya know, keep it in mind. Another way around this is to well, turn the light off between takes and/or use a lower brightness setting. It does stay off 90% of the time in my experience and turning the light off will almost always force the fan to reset.- It's a GREAT light! Honestly, I don't know how it could be much better. It does have the same barn doors as the Yn300 which are probably not the greatest for those of you who know how to really shape light. I'll say the same I said for the YN300 - black wrap is probably going to solve any issues you might have with them.So there's my completely amateur opinion. Good luck!",
#   'overall': 5.0,
#   'summary': 'Another Yongnuo light that I LOVE',
#   'unixReviewTime': 1390867200,
#   'reviewTime': '01 28, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f4'),
#   'reviewerID': 'A1274QVFP1YDOS',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': 'RichCastillo',
#   'helpful': [0, 0],
#   'reviewText': 'I looked at a number of flat panel LEDs and the reviews concerned me because flickering in the video file seems to be a common thread. Although it might not be visible to the human eye, the video clip is the proof. Recall, that the human eye cannot see the 60hz flicker of sodium and metal halide lamps that light our highways. The human eye cannot even see the flicker of 24 frames per second motion picture film. However, a flickering lamp can have an interference effect with the frame rate of the camera and produce zebra like lines that climb or descend the video image. I decided to purchase this based on the Yongnuo name, reasonable price and the nice appearance on the Amazon page.I shot clips on a Canon 6D at 24 fps and 30 fps and at 10% lamp output, 50% and 100%. I saw no evidence of flickering (the moving zebras) in the footage, 6 clips altogether. That\'s great.This unit is a 5 star for me. The exposure on the Canon 6D was ISO 200, 8 feet, 1/30 sec at f/6.3. Pretty respectable. The visual impression is that this lamp is very bright. I did a burn-in of 2+ hours at 100% power and the unit survived. The batteries were drained when I came back. I am using 3rd party Amazon purchased "Sony" 6900 mAh batteries. It takes two and does not come with batteries, so beware. This unit does have a cooling fan that is activated by internal sensor to keep the LEDs from overheating. When the fan comes on the sound can be picked up by a sensitive condenser microphone but I found it to be manageable by using a shotgun mic hung from a boom and processing noise removal in Audition CC. The power is adjustable from 1% to 100% by the same knob that turns the unit on. It is NOT supplied with AC power (an option) but I don\'t find that to be a problem because the unit burns for over an hour on batteries and it is so great not to have to bother with accessing power on location. These lamps are a dream on location because they pack into such a small package and set up so quickly. I was able to shoot an indoor interview with bright sun behind the subject. I used 2 of these lamps (yes, I bought a second one after testing the first) one as a key and another as a fill at 50% output. The bright sun coming in the window acted as the kicker light. My exposure was ISO 200, 1/30sec at f/16. The lamps provided just enough light to properly expose the faces and balance the background. Lamps about 3 to 4 feet from subject. Of course, the closer a lamp is to the subject, the softer the light renders on the subject and since there is no heat projected on the subject the closeness to the subject was not a problem.The IR remote works well and allows remote control of the intensity 1% to 100%. Great to be able to turn the lamp off or adjust intensity when it is extended way up a light stand because is is on batter power, after all.Because I did not have the right adapter with me to mount one of the lamps on my &#8541;" stud light stand, I had to gaffer tape the lamp to the light stand. It held long enough to complete the shoot but came crashing down while breaking down the set. The Yongnuo unit survived the crash with minor scratches, a bent barn door and STILL WORKS. However, one of the batteries was smashed. This is proof enough to me that these lamps can survive some abuse.Highly recommended. I held off writing this review until after I purchased the 2nd lamp and field tested them. Also, I wanted to get my hands on a 2nd one before they become scarce because these are so good.',
#   'overall': 5.0,
#   'summary': 'I was concerned about flicker but there is none.',
#   'unixReviewTime': 1394755200,
#   'reviewTime': '03 14, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f5'),
#   'reviewerID': 'AJZ6BJ38MF78W',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': 'RL',
#   'helpful': [1, 1],
#   'reviewText': "Super amateur videographer here! Needed essentially lighting for YouTube videos. Bought 4 of these plus adapters not via Amazon but the same manufacturer and model number. Tested everything upon arrival. All's well. Great lighting and flexible adjustability between warm and daylight settings. Mine came with remote controls. Very handy! Make sure you know exactly what your net shipping & handling charges are depending on your location.",
#   'overall': 5.0,
#   'summary': 'Blinded by the light - in a good way',
#   'unixReviewTime': 1387670400,
#   'reviewTime': '12 22, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f6'),
#   'reviewerID': 'AK2LF1E4PIJ0L',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': 'S. Baltz',
#   'helpful': [0, 0],
#   'reviewText': "I love this light from start to almost finish.  There is some confusion about this light because there seems to be 2 or 3 versions floating around mostly all under the same banner.  The biggest issue is that at least 1 version comes with an AC power supply, all the rest do not.  Unfortunately, mine did not come with a supply - BUT an included supply was not in the box description so I can't be too upset.  There is an AC supply you can buy for the YN 600 though.  EACHSHOT AC Adapter Power Switching Charger is $22.88 on Amazon.  I would suggest getting one if you plan on using the light for an extended period of time.  For the price, I have not found a better light - heck - for twice the price I haven't found a better light.",
#   'overall': 5.0,
#   'summary': 'Love this light',
#   'unixReviewTime': 1398729600,
#   'reviewTime': '04 29, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f7'),
#   'reviewerID': 'A27ENYAXV82JB4',
#   'asin': 'B00E4LFP0G',
#   'reviewerName': 'SculptStone',
#   'helpful': [2, 2],
#   'reviewText': 'I rate this brilliant light only 5 stars because it comes naked, just the light and no power source.  It seems Yongnuno missed the boat by not including at least an AC power adapter.  Batteries would also make the light really fine.  Having to buy batteries and a charger to make the like even operate is a major, cheap oversight.  It would also be very helpful to have a protective/carrying case included.  Alas!On the positive side: This is bar none the brightest and competitively priced portable LED photo/video light yet.  Once I obtained the high capacity batteries, the light performed spectacularly.  The barn doors serve as protection for the light and even superficially as light baffles/control.The brightness adjustment seems precise and works well.  If they ever include a power source and a case, I would definitely buy a second and third for a very portable and bright lighting package.',
#   'overall': 4.0,
#   'summary': 'Bright, excellent control, BUT',
#   'unixReviewTime': 1391731200,
#   'reviewTime': '02 7, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e00371f8'),
#   'reviewerID': 'A3JSIMK0NKK8NV',
#   'asin': 'B00E4LFWWW',
#   'reviewerName': 'Andrew Barth',
#   'helpful': [0, 0],
#   'reviewText': 'This lasted for about half a year before it stopped reading discs again.  Decided to just buy a super slim.  But hey same thing would of happened if I had Sony fix it.  So I still saved $100, thus the reason why this has 2 stars instead of 1.',
#   'overall': 2.0,
# ...
#   'overall': 5.0,
#   'summary': 'Good Value',
#   'unixReviewTime': 1396483200,
#   'reviewTime': '04 3, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003757e'),
#   'reviewerID': 'A37G4K6DSR391J',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Douglas R McCullough',
#   'helpful': [0, 0],
#   'reviewText': 'There is no need to spend the $40 that is often charged at retail for DVI monitor cables.  These cables may be inexpensive but they are very good quality and worked perfectly.  The shipment was on time and the cables were packaged individually.Not a single negative to this transaction.',
#   'overall': 5.0,
#   'summary': 'On time, great quality, worked perfectly',
#   'unixReviewTime': 1398556800,
#   'reviewTime': '04 27, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003757f'),
#   'reviewerID': 'AQ4A9M5EGI9NY',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Fred',
#   'helpful': [0, 0],
#   'reviewText': 'I have nothing else to say than that it works well and looks like it will for a long time.',
#   'overall': 5.0,
#   'summary': 'Works',
#   'unixReviewTime': 1398297600,
#   'reviewTime': '04 24, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037580'),
#   'reviewerID': 'A1KM8TXVUADXUD',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'GerryR',
#   'helpful': [0, 0],
#   'reviewText': "They're cables - they work.  It's hard to praise cables.",
#   'overall': 5.0,
#   'summary': 'Five Stars',
#   'unixReviewTime': 1405468800,
#   'reviewTime': '07 16, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037581'),
#   'reviewerID': 'A18GI4UOL1S2IO',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'James Stewart "jimmy"',
#   'helpful': [0, 0],
#   'reviewText': 'Great cable, very flexible and high quality. When I need another cable I will be purchasing this one again. Great buy.',
#   'overall': 5.0,
#   'summary': 'Great cable, would buy it again.',
#   'unixReviewTime': 1395964800,
#   'reviewTime': '03 28, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037582'),
#   'reviewerID': 'A19NIDRZK9FKVI',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'jaramill "gjaram"',
#   'helpful': [0, 0],
#   'reviewText': 'I like the gold plating, price was decent and delivery was on-time and it fit my 2nd ASUS VW266H monitor that I had to my video card on my PC that can take up to 4 cards (2 via DVI), 1 via HDMI, 1 via VGA.',
#   'overall': 5.0,
#   'summary': 'Product delivered and fit as described.',
#   'unixReviewTime': 1402963200,
#   'reviewTime': '06 17, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037583'),
#   'reviewerID': 'A10CRW7XRJBJ2G',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'jjme9',
#   'helpful': [0, 0],
#   'reviewText': 'Used this to connect an old computer to my screen,  worked well and allowed me to view the computer, could not ask it to do more then what it was designed to do.',
#   'overall': 4.0,
#   'summary': 'DVI to DVI cord',
#   'unixReviewTime': 1393459200,
#   'reviewTime': '02 27, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037584'),
#   'reviewerID': 'AOTH6V0Y2FMW0',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Khaalis Sanchez',
#   'helpful': [0, 1],
#   'reviewText': "They worked fine for a couple weeks and then one day... nothing. I'm glad I didn't pay more for them.",
#   'overall': 1.0,
#   'summary': 'Thank goodness it was only $6.',
#   'unixReviewTime': 1397779200,
#   'reviewTime': '04 18, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037585'),
#   'reviewerID': 'A3CGCRL81NNOPM',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Lane',
#   'helpful': [0, 0],
#   'reviewText': 'This is a pretty basic product, but it arrived on time without any damage and it does what it is supposed to do.Hooked up my second monitor without any problems',
#   'overall': 5.0,
#   'summary': "it's a cable",
#   'unixReviewTime': 1398729600,
#   'reviewTime': '04 29, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037586'),
#   'reviewerID': 'A2OE4PWO4W6A5P',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'ObeOne',
#   'helpful': [0, 0],
#   'reviewText': "Good product.  Arrived sooner than expected.  Hooked it up to my monitor and works like it should.  Can't say anything special about this cable since it does it's intended purpose.",
#   'overall': 5.0,
#   'summary': 'Good product',
#   'unixReviewTime': 1393200000,
#   'reviewTime': '02 24, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037587'),
#   'reviewerID': 'ARI9AAQGT976R',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'old nerd "Ken P."',
#   'helpful': [0, 0],
#   'reviewText': 'this cable is very flexible and bends corners very easily, gold contact pins and easy to tighten thumb screws. I am glad I made the buy.',
#   'overall': 5.0,
#   'summary': 'flexible cable',
#   'unixReviewTime': 1390003200,
#   'reviewTime': '01 18, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037588'),
#   'reviewerID': 'AYCSG04ZCIU78',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Peter Spaker',
#   'helpful': [0, 0],
#   'reviewText': "There's not much to say about cables that do their job. These work great and were a good deal. Better than good.",
#   'overall': 5.0,
#   'summary': 'Cables that work.... work',
#   'unixReviewTime': 1400025600,
#   'reviewTime': '05 14, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037589'),
#   'reviewerID': 'AQKY26WRR8EF4',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Raymond Bandhan',
#   'helpful': [0, 0],
#   'reviewText': 'My monitor is located a considerable distance from the CPU.I needed a long cable to accommodate the distance without loss of signal quality.This cable fit the bill exactly and works very well.Price is reasonable for a product of this quality.I highly recommend it.',
#   'overall': 5.0,
#   'summary': 'High quality DVI cable',
#   'unixReviewTime': 1393027200,
#   'reviewTime': '02 22, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003758a'),
#   'reviewerID': 'AKS1SJFQ8UG9F',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Richard',
#   'helpful': [0, 0],
#   'reviewText': 'Works as advertised, no problems.I purchased a used monitor and needed a cable for it. Shipped in a reasonable time.',
#   'overall': 5.0,
#   'summary': 'Works well',
#   'unixReviewTime': 1402876800,
#   'reviewTime': '06 16, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003758b'),
#   'reviewerID': 'A3AKM2UEY4I07I',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Robert D. Carter',
#   'helpful': [0, 0],
#   'reviewText': "Couldn't have asked for a better upgrade. When I plugged this baby in I was amazed at how my monitor looked so much better and crisper. Thanks for a great product and well worth the money!",
#   'overall': 4.0,
#   'summary': 'Video cord from heaven!',
#   'unixReviewTime': 1394496000,
#   'reviewTime': '03 11, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003758c'),
#   'reviewerID': 'AP86I2GHQDU9I',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Robert G. Koontz',
#   'helpful': [0, 0],
#   'reviewText': 'The cable was very good. It went well with the hook-up of my new monitor. Reasonably priced. Local cable was $20.00. Good savings',
#   'overall': 4.0,
#   'summary': 'DVI cable',
#   'unixReviewTime': 1400976000,
#   'reviewTime': '05 25, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003758d'),
#   'reviewerID': 'A32UDXKMYR06TO',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Ross Nakatsuji "TechnoGeek"',
#   'helpful': [0, 0],
#   'reviewText': "Buy these cables. They are great. There is no reason to pay retail. Make sure you don't need the dual-link version.",
#   'overall': 5.0,
#   'summary': 'Great performance and price',
#   'unixReviewTime': 1399507200,
#   'reviewTime': '05 8, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003758e'),
#   'reviewerID': 'A3KM7XDB2IMPIM',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'S. Larson',
#   'helpful': [0, 0],
#   'reviewText': 'After checking prices in retail outlets for a longer cable of this type, I was both surprised and pleased to see the prices offered on-line. The delivery was quick, the price was very reasonable, and the product performed as it should. What more could one want?',
#   'overall': 5.0,
#   'summary': 'Quick Delivery and Reasonably-Priced',
#   'unixReviewTime': 1394841600,
#   'reviewTime': '03 15, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003758f'),
#   'reviewerID': 'A1MLVC3N4OQSTK',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'Steve',
#   'helpful': [0, 0],
#   'reviewText': 'This cord is well-made and worked perfectly to connect my computer tower to my HD monitor. I recommend this product highly.',
#   'overall': 5.0,
#   'summary': 'High Quality Cord',
#   'unixReviewTime': 1400371200,
#   'reviewTime': '05 18, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037590'),
#   'reviewerID': 'A2EQAC7C8VYYW1',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'The Stas',
#   'helpful': [0, 0],
#   'reviewText': "I don't understand why people buy expensive cords. This cord works perfectly and I have yet to have ANY type of issue.",
#   'overall': 5.0,
#   'summary': 'Perfect cord',
#   'unixReviewTime': 1394409600,
#   'reviewTime': '03 10, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037591'),
#   'reviewerID': 'A23NLTYYFSPB1A',
#   'asin': 'B00E4YG1RE',
#   'reviewerName': 'WM "wm"',
#   'helpful': [0, 0],
#   'reviewText': 'Instead of dealing with packaging & returning - I just out it the trash.... You can see the quality on the gold color end - super cheaply made - it looks like someone made it by hand.. Wish Amazon has Zero star.',
#   'overall': 1.0,
#   'summary': 'It did not work...',
#   'unixReviewTime': 1401753600,
#   'reviewTime': '06 3, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037592'),
#   'reviewerID': 'A1T0YOPZ9PQPF5',
#   'asin': 'B00E4YHBOQ',
#   'reviewerName': 'Carolyn Hunt',
#   'helpful': [0, 0],
#   'reviewText': "This skin was used to mark the door of a photo studio film room.  It prevents anyone from mistaking the room for the men's or women's facilities.",
#   'overall': 4.0,
#   'summary': 'Film camera decal skin',
#   'unixReviewTime': 1400630400,
#   'reviewTime': '05 21, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037593'),
#   'reviewerID': 'AR3BM714GO6AE',
#   'asin': 'B00E4YHBOQ',
#   'reviewerName': 'Joanna Brickus',
#   'helpful': [0, 0],
#   'reviewText': "I got this to go on my daughter's mac and it was cuter that in the pictures. Very nice and came quick",
#   'overall': 4.0,
#   'summary': 'Adorable',
#   'unixReviewTime': 1400630400,
#   'reviewTime': '05 21, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037594'),
#   'reviewerID': 'A3DIF048DZVUE0',
#   'asin': 'B00E4YHBOQ',
#   'reviewerName': 'Keila Zamora',
#   'helpful': [0, 0],
#   'reviewText': 'it fits perfectly on my macbook pro. it is difficult to put on because of the size, i put it on and it got air bubbles but it looks great. love this hopefully it will last',
#   'overall': 4.0,
#   'summary': 'great',
#   'unixReviewTime': 1400198400,
#   'reviewTime': '05 16, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037595'),
#   'reviewerID': 'A7PDXUH17G2YO',
#   'asin': 'B00E4YKEFY',
#   'reviewerName': 'Rodney L Hendrix',
#   'helpful': [0, 0],
#   'reviewText': 'Beautiful to look at.....for about a week then the finish completely tarnished.  I could live with that but THEN it started losing data files.  It finally just quit.  If you bought one, I hope you had better luck with it than I did.',
#   'overall': 1.0,
#   'summary': 'Junk',
#   'unixReviewTime': 1394150400,
#   'reviewTime': '03 7, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037596'),
#   'reviewerID': 'A2AV0YTVRUHF1P',
#   'asin': 'B00E4YKR1U',
#   'reviewerName': 'Arlene Norman',
#   'helpful': [4, 13],
#   'reviewText': 'I have a 17.3&#34; HP laptop and should have stopped there. I have had so much frustration from my first computer, in fact, I had decided to replace it. I spotted the Pro Book with 8GB of RAM and wondered whether I should give HP another chance. Wow, this one is a piece of crap. It worked long enough for me to load all my data and pictures and then quit on the second day. Nothing. It quit.  The 17&#34; crashed and I tried to back up my data. Nothing saved. No more chances for HP laptops.',
#   'overall': 1.0,
#   'summary': 'I will never touch another HP laptop again',
#   'unixReviewTime': 1382832000,
#   'reviewTime': '10 27, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037597'),
#   'reviewerID': 'AXYHGG5606NFJ',
#   'asin': 'B00E4YKR1U',
#   'reviewerName': 'B. Parker',
#   'helpful': [8, 9],
#   'reviewText': "I have an 11 yr old with special needs. He uses his elbows and as such can't use a touchscreen electronic. He used to have a WinXP desktop that WinXP support ends next year and needs a new OS. So this Hewlett Packard computer with Windows 7 was great. I got him this in place of Windows 8 which he can't use his programs on. Great laptop",
#   'overall': 5.0,
#   'summary': 'Great Computer',
#   'unixReviewTime': 1380412800,
#   'reviewTime': '09 29, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037598'),
#   'reviewerID': 'A2SILQLEFWT9B6',
#   'asin': 'B00E4YKR1U',
#   'reviewerName': 'C. Hayhoe "chayhoe"',
#   'helpful': [5, 7],
#   'reviewText': 'The computer runs great after I took all the HP security tools off.  They were not compatible with recognizing my printer and running my real estate programs.  Wish they would not be automatically installed. Things are running smoothly now with a great picture. Hate the tiny delete button though. It is in a hard to find position and should be larger.',
#   'overall': 4.0,
#   'summary': 'Hate the HP security programs on there.',
#   'unixReviewTime': 1382745600,
#   'reviewTime': '10 26, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e0037599'),
#   'reviewerID': 'A1KPCOM7WQGP2E',
#   'asin': 'B00E4YKR1U',
#   'reviewerName': 'Chaz',
#   'helpful': [5, 5],
#   'reviewText': "Great specs here for the price. Gotta love Windows 7, and it doesn't hurt that they threw in Windows 8 license just in case you want to upgrade. Fast and quiet machine. Came with a lot of bloatware which I uninstalled immediately. The only problem I have is with the  keyboard buttons for adjusting the volume and brightness. It's a major pain to have to be holding the &#34;fn&#34; button to utilize these features. In fact, the brightness adjustment buttons aren't working at all. I will still live, but the keyboard is a disappointment. My previous HP laptop did not require holding any key combinations to have to change the volume and brightness from the keyboard. I still recommend the product for its performance and value.",
#   'overall': 4.0,
#   'summary': 'Love It',
#   'unixReviewTime': 1391212800,
#   'reviewTime': '02 1, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003759a'),
#   'reviewerID': 'A37CHW0U87BJ5Y',
#   'asin': 'B00E4YKR1U',
#   'reviewerName': 'Cheryl Arn',
#   'helpful': [0, 0],
#   'reviewText': 'I like this laptop.  It is a little heavy.  Everything I need to do this is just fine for me.',
#   'overall': 5.0,
#   'summary': 'Great',
#   'unixReviewTime': 1395878400,
#   'reviewTime': '03 27, 2014'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003759b'),
#   'reviewerID': 'A19BVX2Z1RW8GT',
#   'asin': 'B00E4YKR1U',
#   'reviewerName': 'DaveS',
#   'helpful': [7, 8],
#   'reviewText': 'Very pleased with the unit.  Exactly what I ordered.  No complaints.  It is an enjoyable experience to have web pages and applications up in milliseconds rather than minutes.',
#   'overall': 5.0,
#   'summary': 'Satisfied Customer',
#   'unixReviewTime': 1383955200,
#   'reviewTime': '11 9, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003759c'),
#   'reviewerID': 'AWDNSAXALOK0U',
#   'asin': 'B00E4YKR1U',
#   'reviewerName': 'dkittykat "dvd  collector"',
#   'helpful': [4, 6],
#   'reviewText': 'It is a great laptop. The only problems are the ones I create as i am not a computer wizard!',
#   'overall': 5.0,
#   'summary': 'Just what I wanted!',
#   'unixReviewTime': 1385164800,
#   'reviewTime': '11 23, 2013'},
#  {'_id': ObjectId('5e5ca1dfb2b52b52e003759d'),
#   'reviewerID': 'A1O5IOW5B5FPJK',
#   'asin': 'B00E4YKR1U',
#   'reviewerName': 'douglas fuller',
#   'helpful': [2, 3],
#   'reviewText': "Okay computer. Good processing power for a laptop. A little heavy and it came loaded with tons of adware that has been a real pain, although i can't blame the hardware for that, either hp or the vendor is to blame. not sure.",
#   'overall': 4.0,
#   'summary': 'consumer review of blah, blah, blah',
#   'unixReviewTime': 1394150400,
#   'reviewTime': '03 7, 2014'},
#  ...]

# %% [markdown]
# ### (2) writes that content to “electronics_SQL” in SQL. Print the first 25 documents to the screen.

# %%
# for el in result_list:
#     # deal with the objectid, or you can create the primary key yourself by using incremented.
    
#     # format the reviewTime
#     el["reviewTime"] = datetime.strptime(el["reviewTime"],'%m %d, %Y').date()
#     el["reviewTime"] = datetime.strftime(el["reviewTime"],'%Y-%m-%d')
    
#     # convert helpful to string
#     el["helpful"] = str(el["helpful"])
    
#     # deal with missing reviewerName
#     if "reviewerName" not in el.keys():
#         el["reviewerName"] = None
        
# val_to_insert = result_list

# %%
results_df = pd.DataFrame(results_list)

# clean the id column, which is bson id type.
results_df["_id"] = results_df['_id'].astype(str)
results_df['_id'].replace('("ObjectId")','',regex=True, inplace = True)

# drop the review text column
results_df.drop(["reviewText"], axis = 1, inplace=True)

# format the reviewTime
results_df["reviewTime"] = pd.to_datetime(results_df["reviewTime"]).dt.date.astype(str)

# change the helpful format to string
results_df["helpful"] = results_df["helpful"].astype(str)

# change the nan values in dataframe to be None so as to be detected by MySQL
results_df = results_df.where(pd.notnull(results_df), None)

val_to_insert = results_df.values.tolist()

# %%
conn = pymysql.connect(host='localhost', user = 'root', password = pw, database=SQL_DB)
cursor = conn.cursor()

sql = "INSERT INTO "+ SQL_table + ("(id, asin,helpful,overall,reviewTime,reviewerID,"
                                   "reviewerName,summary,unixReviewTime)"
                                   " VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)")

try:
    cursor.executemany(sql, val_to_insert)
    conn.commit()
    
except pymysql.IntegrityError:
    print('already exists in the database.')

conn.close()

# %%
conn = pymysql.connect(host='localhost', user = 'root', password = pw, database=SQL_DB)

SQL_Query = pd.read_sql_query(
'''
SELECT * FROM electronics_SQL
LIMIT 25;
''', conn)

SQL_Query

conn.close()
# Out:
#                           id      reviewerID        asin  \
# 0   5e5ca1dfb2b52b52e00371b6   AKM1MP6P0OYPR  0132793040
# 1   5e5ca1dfb2b52b52e00371b7  A2X8VX4DPMQFQQ  B00E4KP4W6
# 2   5e5ca1dfb2b52b52e00371b8  A1JEKX4D58576X  B00E4KP4W6
# 3   5e5ca1dfb2b52b52e00371b9   ATM6RRB90D8DV  B00E4KP4W6
# 4   5e5ca1dfb2b52b52e00371ba  A3QOYJ97A6OMX7  B00E4KP4W6
# 5   5e5ca1dfb2b52b52e00371bb   AWO84NZ6VDYR2  B00E4KP4W6
# 6   5e5ca1dfb2b52b52e00371bc  A15ZEBTKX72NPB  B00E4KP4W6
# 7   5e5ca1dfb2b52b52e00371bd  A2ZI014DO0LWEW  B00E4KP4W6
# 8   5e5ca1dfb2b52b52e00371be  A3IN9CE5GG8VKR  B00E4KP4W6
# 9   5e5ca1dfb2b52b52e00371bf  A1U9ZR7HQ5EZ6L  B00E4KP4W6
# 10  5e5ca1dfb2b52b52e00371c0  A2DFGG75NH91H2  B00E4KP4W6
# 11  5e5ca1dfb2b52b52e00371c1   ADTAGIHSU42HH  B00E4KP4W6
# 12  5e5ca1dfb2b52b52e00371c2  A2QXOUHUL5CDT5  B00E4KP8VI
# 13  5e5ca1dfb2b52b52e00371c3  A1YQI2Y7DRYFZL  B00E4KPMC8
# 14  5e5ca1dfb2b52b52e00371c4   AWFP70TL8BF43  B00E4KPMC8
# 15  5e5ca1dfb2b52b52e00371c5  A1T7SJ8JMCIIZ8  B00E4KPMC8
# 16  5e5ca1dfb2b52b52e00371c6  A2QO3GRUYBVDX5  B00E4KQ5C4
# 17  5e5ca1dfb2b52b52e00371c7   AQ1VEA1RAXMJM  B00E4KQ9GG
# 18  5e5ca1dfb2b52b52e00371c8  A28YUFBI33QZ28  B00E4KQ9GG
# 19  5e5ca1dfb2b52b52e00371c9  A1EN2PR6V7F87Z  B00E4KQ9GG
# 20  5e5ca1dfb2b52b52e00371ca  A1Y109DY2NSQYP  B00E4KQ9GG
# 21  5e5ca1dfb2b52b52e00371cb  A1W8TUEAXHF1H9  B00E4KQ9GG
# 22  5e5ca1dfb2b52b52e00371cc  A2U0VQAQHEFB1Y  B00E4KQ9GG
# 23  5e5ca1dfb2b52b52e00371cd  A17970XJG2BYIA  B00E4KQ9GG
# 24  5e5ca1dfb2b52b52e00371ce   A6EAQI9PSIFP5  B00E4KQ9K2
#
#                    reviewerName helpful  overall  \
# 0          Vicki Gibson "momo4"  [1, 1]        5
# 1                        lily68  [1, 1]        5
# 2                 Mara Milagros  [2, 2]        5
# 3   Matthew D. Irmen "Jazz Fan"  [1, 2]        4
# 4                   pharmdaddyd  [1, 1]        5
# 5              shalane rogillio  [0, 0]        1
# 6           S. Marcus "pdtpoet"  [1, 2]        5
# 7                       SueinCa  [0, 0]        5
# 8                    Tess Brown  [0, 0]        5
# 9                    Thinker623  [1, 1]        5
# 10                      Thuddds  [0, 0]        5
# 11                     Wvmtnivy  [1, 1]        5
# 12                  Cassi Olsen  [0, 0]        5
# 13                          HBP  [1, 1]        2
# 14                   PJ "Peter"  [1, 1]        3
# 15            Tracey Wesolowski  [1, 1]        1
# 16           Alexander Cornwell  [1, 1]        5
# 17    Amazon Customer "Annette"  [1, 1]        4
# 18              Amazon Customer  [4, 4]        5
# 19                         Anne  [1, 1]        3
# 20               Barry Palacios  [0, 1]        2
# 21                  Carlos Seer  [1, 1]        5
# 22                       DaddyO  [1, 1]        3
# 23                   Linzee1998  [1, 2]        1
# 24              Amazon Customer  [0, 0]        5
#
#                                               summary  unixReviewTime  \
# 0                                       Very thorough      1365811200
# 1                        LOVE this screen protector!!      1393459200
# 2                                           excellent      1394496000
# 3   Nice looking, easy to install glass screen pro...      1393891200
# 4                                 great for the price      1388361600
# 5            Not happy with this, would not recommend      1404777600
# 6    Far better than film screens for iPhone or iPad!      1392249600
# 7                                            Right On      1397174400
# 8                     Tempered Glass Screen Protector      1399593600
# 9                         Great glass cover for IPad.      1391126400
# 10                                          Excellent      1399420800
# 11                              Nice screen protector      1385251200
# 12                           Great headset for cheap.      1379030400
# 13                           Will not tilt horizontal      1393459200
# 14                                  Not what I needed      1393027200
# 15                                   DO NOT PURCHASE!      1392595200
# 16                                               How?      1388707200
# 17     nice fitting case for the samsung galaxy tab 3      1390953600
# 18                                   Top notch case !      1385164800
# 19                          thin but not the best fit      1400371200
# 20                               not worth the money!      1389571200
# 21                                      excelent case      1395100800
# 22               Beautiful design, good quality...but      1389139200
# 23                                        Doesnt fit!      1387929600
# 24                                              great      1395619200
#
#     ReviewTime
# 0   2013-04-13
# 1   2014-02-27
# 2   2014-03-11
# 3   2014-03-04
# 4   2013-12-30
# 5   2014-07-08
# 6   2014-02-13
# 7   2014-04-11
# 8   2014-05-09
# 9   2014-01-31
# 10  2014-05-07
# 11  2013-11-24
# 12  2013-09-13
# 13  2014-02-27
# 14  2014-02-22
# 15  2014-02-17
# 16  2014-01-03
# 17  2014-01-29
# 18  2013-11-23
# 19  2014-05-18
# 20  2014-01-13
# 21  2014-03-18
# 22  2014-01-08
# 23  2013-12-25
# 24  2014-03-24

# %% [markdown]
# ## Map Reduce to create collection "avg_scores" by product.

# %%
mapper_1 = Code("""
                    function () { emit(this.asin, this.overall)}
                """)


reducer_1 = Code("""
                   function(key, value) { return Array.avg(value) }
                 """)
query_1 = {"overall":{'$exists':1}}

# %%
avg_review = coll.map_reduce(mapper_1, reducer_1, "avg_scores", query=query_1)

# %%
# first 100 entries of avg_reviews
avg_review_df = pd.DataFrame(list(avg_review.find().limit(100)))
avg_review_df
# Out:
#            _id     value
# 0   0132793040  5.000000
# 1   B00E4KP4W6  4.545455
# 2   B00E4KP8VI  5.000000
# 3   B00E4KPMC8  2.000000
# 4   B00E4KQ5C4  5.000000
# 5   B00E4KQ9GG  3.285714
# 6   B00E4KQ9K2  5.000000
# 7   B00E4KQD4E  4.000000
# 8   B00E4KZBX8  4.000000
# 9   B00E4KZDJ0  5.000000
# 10  B00E4L35DA  4.000000
# 11  B00E4L3N9Q  4.000000
# 12  B00E4L48EA  5.000000
# 13  B00E4L7FLI  1.000000
# 14  B00E4L7TS2  4.000000
# 15  B00E4LAL82  3.000000
# 16  B00E4LBZZK  5.000000
# 17  B00E4LF2Z4  4.333333
# 18  B00E4LFP0G  4.444444
# 19  B00E4LFWWW  4.400000
# 20  B00E4LGTVU  4.195659
# 21  B00E4LGTXS  3.923077
# 22  B00E4LGVYA  3.272727
# 23  B00E4LGWLW  3.500000
# 24  B00E4LGXL6  5.000000
# 25  B00E4LGY88  3.842105
# 26  B00E4LI86O  1.000000
# 27  B00E4LJ8VI  1.666667
# 28  B00E4LQ9B0  1.000000
# 29  B00E4M2K08  5.000000
# ..         ...       ...
# 70  B00E4RZV6S  3.750000
# 71  B00E4RZW44  3.000000
# 72  B00E4RZYMO  1.000000
# 73  B00E4S5BQ2  5.000000
# 74  B00E4SDU0Q  1.000000
# 75  B00E4SEBAY  5.000000
# 76  B00E4SPPHW  3.666667
# 77  B00E4T58NC  2.676471
# 78  B00E4T699E  3.000000
# 79  B00E4T69DK  5.000000
# 80  B00E4T6MWI  2.000000
# 81  B00E4T7GP0  2.000000
# 82  B00E4T7VOG  5.000000
# 83  B00E4T8XZC  4.666667
# 84  B00E4TADN2  3.000000
# 85  B00E4TASKK  3.500000
# 86  B00E4TBST0  5.000000
# 87  B00E4TEKC2  5.000000
# 88  B00E4TKYOU  5.000000
# 89  B00E4TN3MA  1.000000
# 90  B00E4TOWR0  3.000000
# 91  B00E4TV36I  5.000000
# 92  B00E4TWMWC  1.000000
# 93  B00E4U83B0  3.133333
# 94  B00E4UA7SW  4.571429
# 95  B00E4UD9TQ  4.666667
# 96  B00E4UGIVC  3.000000
# 97  B00E4UGJV6  4.000000
# 98  B00E4UIU1I  5.000000
# 99  B00E4UVVYG  5.000000
#
# [100 rows x 2 columns]

# %%
for avg_score in avg_review.find().limit(100):
    print(avg_score)
# Out:
# {'_id': '0132793040', 'value': 5.0}
# {'_id': 'B00E4KP4W6', 'value': 4.545454545454546}
# {'_id': 'B00E4KP8VI', 'value': 5.0}
# {'_id': 'B00E4KPMC8', 'value': 2.0}
# {'_id': 'B00E4KQ5C4', 'value': 5.0}
# {'_id': 'B00E4KQ9GG', 'value': 3.2857142857142856}
# {'_id': 'B00E4KQ9K2', 'value': 5.0}
# {'_id': 'B00E4KQD4E', 'value': 4.0}
# {'_id': 'B00E4KZBX8', 'value': 4.0}
# {'_id': 'B00E4KZDJ0', 'value': 5.0}
# {'_id': 'B00E4L35DA', 'value': 4.0}
# {'_id': 'B00E4L3N9Q', 'value': 4.0}
# {'_id': 'B00E4L48EA', 'value': 5.0}
# {'_id': 'B00E4L7FLI', 'value': 1.0}
# {'_id': 'B00E4L7TS2', 'value': 4.0}
# {'_id': 'B00E4LAL82', 'value': 3.0}
# {'_id': 'B00E4LBZZK', 'value': 5.0}
# {'_id': 'B00E4LF2Z4', 'value': 4.333333333333333}
# {'_id': 'B00E4LFP0G', 'value': 4.444444444444445}
# {'_id': 'B00E4LFWWW', 'value': 4.4}
# {'_id': 'B00E4LGTVU', 'value': 4.195658625514055}
# {'_id': 'B00E4LGTXS', 'value': 3.923076923076923}
# {'_id': 'B00E4LGVYA', 'value': 3.272727272727273}
# {'_id': 'B00E4LGWLW', 'value': 3.5}
# {'_id': 'B00E4LGXL6', 'value': 5.0}
# {'_id': 'B00E4LGY88', 'value': 3.8421052631578947}
# {'_id': 'B00E4LI86O', 'value': 1.0}
# {'_id': 'B00E4LJ8VI', 'value': 1.6666666666666667}
# {'_id': 'B00E4LQ9B0', 'value': 1.0}
# {'_id': 'B00E4M2K08', 'value': 5.0}
# {'_id': 'B00E4M3KW0', 'value': 4.0}
# {'_id': 'B00E4M9H40', 'value': 3.3333333333333335}
# {'_id': 'B00E4MC3LO', 'value': 2.0}
# {'_id': 'B00E4MHBOI', 'value': 3.0}
# {'_id': 'B00E4ML766', 'value': 5.0}
# {'_id': 'B00E4MNXYA', 'value': 5.0}
# {'_id': 'B00E4MQO8C', 'value': 4.933333333333334}
# {'_id': 'B00E4MQODW', 'value': 2.6666666666666665}
# {'_id': 'B00E4MQOE6', 'value': 4.611111111111111}
# {'_id': 'B00E4MT07Y', 'value': 1.6}
# {'_id': 'B00E4MVHTI', 'value': 3.9}
# {'_id': 'B00E4MYDTY', 'value': 4.538461538461538}
# {'_id': 'B00E4NC912', 'value': 5.0}
# {'_id': 'B00E4O3CD0', 'value': 4.0}
# {'_id': 'B00E4O7EO8', 'value': 4.2}
# {'_id': 'B00E4OCCJK', 'value': 5.0}
# {'_id': 'B00E4OCECU', 'value': 3.0}
# {'_id': 'B00E4OHBNM', 'value': 4.0}
# {'_id': 'B00E4OHRJ0', 'value': 4.0}
# {'_id': 'B00E4OI5H8', 'value': 5.0}
# {'_id': 'B00E4OKJKY', 'value': 5.0}
# {'_id': 'B00E4OKJUE', 'value': 1.0}
# {'_id': 'B00E4OKZA8', 'value': 5.0}
# {'_id': 'B00E4ON1YK', 'value': 5.0}
# {'_id': 'B00E4OSIO8', 'value': 5.0}
# {'_id': 'B00E4PM406', 'value': 4.0}
# {'_id': 'B00E4PMDIO', 'value': 5.0}
# {'_id': 'B00E4POW42', 'value': 5.0}
# {'_id': 'B00E4PP8PY', 'value': 4.0}
# {'_id': 'B00E4QD7D8', 'value': 4.0}
# {'_id': 'B00E4QM3TC', 'value': 1.0}
# {'_id': 'B00E4QX5J4', 'value': 2.0}
# {'_id': 'B00E4RD4VC', 'value': 4.375}
# {'_id': 'B00E4RIYPI', 'value': 4.5}
# {'_id': 'B00E4RKKVY', 'value': 4.0}
# {'_id': 'B00E4RS3DG', 'value': 4.5}
# {'_id': 'B00E4RUZGO', 'value': 2.0}
# {'_id': 'B00E4RZOQ0', 'value': 5.0}
# {'_id': 'B00E4RZQM2', 'value': 2.6}
# {'_id': 'B00E4RZU00', 'value': 4.0}
# {'_id': 'B00E4RZV6S', 'value': 3.75}
# {'_id': 'B00E4RZW44', 'value': 3.0}
# {'_id': 'B00E4RZYMO', 'value': 1.0}
# {'_id': 'B00E4S5BQ2', 'value': 5.0}
# {'_id': 'B00E4SDU0Q', 'value': 1.0}
# {'_id': 'B00E4SEBAY', 'value': 5.0}
# {'_id': 'B00E4SPPHW', 'value': 3.6666666666666665}
# {'_id': 'B00E4T58NC', 'value': 2.676470588235294}
# {'_id': 'B00E4T699E', 'value': 3.0}
# {'_id': 'B00E4T69DK', 'value': 5.0}
# {'_id': 'B00E4T6MWI', 'value': 2.0}
# {'_id': 'B00E4T7GP0', 'value': 2.0}
# {'_id': 'B00E4T7VOG', 'value': 5.0}
# {'_id': 'B00E4T8XZC', 'value': 4.666666666666667}
# {'_id': 'B00E4TADN2', 'value': 3.0}
# {'_id': 'B00E4TASKK', 'value': 3.5}
# {'_id': 'B00E4TBST0', 'value': 5.0}
# {'_id': 'B00E4TEKC2', 'value': 5.0}
# {'_id': 'B00E4TKYOU', 'value': 5.0}
# {'_id': 'B00E4TN3MA', 'value': 1.0}
# {'_id': 'B00E4TOWR0', 'value': 3.0}
# {'_id': 'B00E4TV36I', 'value': 5.0}
# {'_id': 'B00E4TWMWC', 'value': 1.0}
# {'_id': 'B00E4U83B0', 'value': 3.1333333333333333}
# {'_id': 'B00E4UA7SW', 'value': 4.571428571428571}
# {'_id': 'B00E4UD9TQ', 'value': 4.666666666666667}
# {'_id': 'B00E4UGIVC', 'value': 3.0}
# {'_id': 'B00E4UGJV6', 'value': 4.0}
# {'_id': 'B00E4UIU1I', 'value': 5.0}
# {'_id': 'B00E4UVVYG', 'value': 5.0}

# %% [markdown]
# ## Map Reduce to create collection "weighted_avg_scores" by product.

# %%
mapper_2 = Code("""
                    function () { 
                        var key = this.asin;
                        var values = {wtd_scores: (this.helpful[0]+1)*this.overall, wt:(this.helpful[0]+1)};
                        emit(key, values);
                    }
                """)

reducer_2 = Code("""
                    function(key, value) {
                        var tot = {wtd_scores:0, wt:0};
                        for (var idx = 0; idx<value.length; idx++){
                             tot.wtd_scores += value[idx].wtd_scores;
                             tot.wt += value[idx].wt;
                        };
                    return tot; 
                    }
                 """)

finalizer = Code("""
                    function (key, tot){
                    wtd_avg = tot.wtd_scores/tot.wt;
                    return wtd_avg; 
                    }
                 """)
query_2 = {"overall": {'$exists':1}}

# %%
wtd_review = coll.map_reduce(map=mapper_2, reduce=reducer_2, out="weighted_avg", query=query_2, finalize=finalizer)

# %%
# first 100 entries of avg_reviews
wtd_review_df = pd.DataFrame(list(wtd_review.find().limit(100)))
wtd_review_df
# Out:
#            _id     value
# 0   0132793040  5.000000
# 1   B00E4KP4W6  4.684211
# 2   B00E4KP8VI  5.000000
# 3   B00E4KPMC8  2.000000
# 4   B00E4KQ5C4  5.000000
# 5   B00E4KQ9GG  3.687500
# 6   B00E4KQ9K2  5.000000
# 7   B00E4KQD4E  4.000000
# 8   B00E4KZBX8  4.000000
# 9   B00E4KZDJ0  5.000000
# 10  B00E4L35DA  3.000000
# 11  B00E4L3N9Q  4.000000
# 12  B00E4L48EA  5.000000
# 13  B00E4L7FLI  1.000000
# 14  B00E4L7TS2  4.000000
# 15  B00E4LAL82  3.000000
# 16  B00E4LBZZK  5.000000
# 17  B00E4LF2Z4  4.153846
# 18  B00E4LFP0G  4.434783
# 19  B00E4LFWWW  4.400000
# 20  B00E4LGTVU  3.906452
# 21  B00E4LGTXS  4.000000
# 22  B00E4LGVYA  3.800000
# 23  B00E4LGWLW  3.818182
# 24  B00E4LGXL6  5.000000
# 25  B00E4LGY88  4.248408
# 26  B00E4LI86O  1.000000
# 27  B00E4LJ8VI  1.666667
# 28  B00E4LQ9B0  1.000000
# 29  B00E4M2K08  5.000000
# ..         ...       ...
# 70  B00E4RZV6S  3.750000
# 71  B00E4RZW44  3.000000
# 72  B00E4RZYMO  1.000000
# 73  B00E4S5BQ2  5.000000
# 74  B00E4SDU0Q  1.000000
# 75  B00E4SEBAY  5.000000
# 76  B00E4SPPHW  2.689655
# 77  B00E4T58NC  3.206061
# 78  B00E4T699E  3.000000
# 79  B00E4T69DK  5.000000
# 80  B00E4T6MWI  2.000000
# 81  B00E4T7GP0  2.000000
# 82  B00E4T7VOG  5.000000
# 83  B00E4T8XZC  4.750000
# 84  B00E4TADN2  3.000000
# 85  B00E4TASKK  3.500000
# 86  B00E4TBST0  5.000000
# 87  B00E4TEKC2  5.000000
# 88  B00E4TKYOU  5.000000
# 89  B00E4TN3MA  1.000000
# 90  B00E4TOWR0  3.000000
# 91  B00E4TV36I  5.000000
# 92  B00E4TWMWC  1.000000
# 93  B00E4U83B0  2.700000
# 94  B00E4UA7SW  4.769231
# 95  B00E4UD9TQ  4.666667
# 96  B00E4UGIVC  3.000000
# 97  B00E4UGJV6  4.000000
# 98  B00E4UIU1I  5.000000
# 99  B00E4UVVYG  5.000000
#
# [100 rows x 2 columns]

# %%
for wtd_score in wtd_review.find().limit(100):
    print(wtd_score)
# Out:
# {'_id': '0132793040', 'value': 5.0}
# {'_id': 'B00E4KP4W6', 'value': 4.684210526315789}
# {'_id': 'B00E4KP8VI', 'value': 5.0}
# {'_id': 'B00E4KPMC8', 'value': 2.0}
# {'_id': 'B00E4KQ5C4', 'value': 5.0}
# {'_id': 'B00E4KQ9GG', 'value': 3.6875}
# {'_id': 'B00E4KQ9K2', 'value': 5.0}
# {'_id': 'B00E4KQD4E', 'value': 4.0}
# {'_id': 'B00E4KZBX8', 'value': 4.0}
# {'_id': 'B00E4KZDJ0', 'value': 5.0}
# {'_id': 'B00E4L35DA', 'value': 3.0}
# {'_id': 'B00E4L3N9Q', 'value': 4.0}
# {'_id': 'B00E4L48EA', 'value': 5.0}
# {'_id': 'B00E4L7FLI', 'value': 1.0}
# {'_id': 'B00E4L7TS2', 'value': 4.0}
# {'_id': 'B00E4LAL82', 'value': 3.0}
# {'_id': 'B00E4LBZZK', 'value': 5.0}
# {'_id': 'B00E4LF2Z4', 'value': 4.153846153846154}
# {'_id': 'B00E4LFP0G', 'value': 4.434782608695652}
# {'_id': 'B00E4LFWWW', 'value': 4.4}
# {'_id': 'B00E4LGTVU', 'value': 3.9064516129032256}
# {'_id': 'B00E4LGTXS', 'value': 4.0}
# {'_id': 'B00E4LGVYA', 'value': 3.8}
# {'_id': 'B00E4LGWLW', 'value': 3.8181818181818183}
# {'_id': 'B00E4LGXL6', 'value': 5.0}
# {'_id': 'B00E4LGY88', 'value': 4.248407643312102}
# {'_id': 'B00E4LI86O', 'value': 1.0}
# {'_id': 'B00E4LJ8VI', 'value': 1.6666666666666667}
# {'_id': 'B00E4LQ9B0', 'value': 1.0}
# {'_id': 'B00E4M2K08', 'value': 5.0}
# {'_id': 'B00E4M3KW0', 'value': 4.0}
# {'_id': 'B00E4M9H40', 'value': 3.25}
# {'_id': 'B00E4MC3LO', 'value': 2.0}
# {'_id': 'B00E4MHBOI', 'value': 3.0}
# {'_id': 'B00E4ML766', 'value': 5.0}
# {'_id': 'B00E4MNXYA', 'value': 5.0}
# {'_id': 'B00E4MQO8C', 'value': 4.978260869565218}
# {'_id': 'B00E4MQODW', 'value': 2.6470588235294117}
# {'_id': 'B00E4MQOE6', 'value': 4.674418604651163}
# {'_id': 'B00E4MT07Y', 'value': 1.3125}
# {'_id': 'B00E4MVHTI', 'value': 4.0}
# {'_id': 'B00E4MYDTY', 'value': 4.133333333333334}
# {'_id': 'B00E4NC912', 'value': 5.0}
# {'_id': 'B00E4O3CD0', 'value': 4.0}
# {'_id': 'B00E4O7EO8', 'value': 4.230769230769231}
# {'_id': 'B00E4OCCJK', 'value': 5.0}
# {'_id': 'B00E4OCECU', 'value': 3.5}
# {'_id': 'B00E4OHBNM', 'value': 4.0}
# {'_id': 'B00E4OHRJ0', 'value': 4.0}
# {'_id': 'B00E4OI5H8', 'value': 5.0}
# {'_id': 'B00E4OKJKY', 'value': 5.0}
# {'_id': 'B00E4OKJUE', 'value': 1.0}
# {'_id': 'B00E4OKZA8', 'value': 5.0}
# {'_id': 'B00E4ON1YK', 'value': 5.0}
# {'_id': 'B00E4OSIO8', 'value': 5.0}
# {'_id': 'B00E4PM406', 'value': 4.0}
# {'_id': 'B00E4PMDIO', 'value': 5.0}
# {'_id': 'B00E4POW42', 'value': 5.0}
# {'_id': 'B00E4PP8PY', 'value': 4.0}
# {'_id': 'B00E4QD7D8', 'value': 4.0}
# {'_id': 'B00E4QM3TC', 'value': 1.0}
# {'_id': 'B00E4QX5J4', 'value': 2.0}
# {'_id': 'B00E4RD4VC', 'value': 4.545454545454546}
# {'_id': 'B00E4RIYPI', 'value': 4.333333333333333}
# {'_id': 'B00E4RKKVY', 'value': 4.0}
# {'_id': 'B00E4RS3DG', 'value': 4.5}
# {'_id': 'B00E4RUZGO', 'value': 2.2941176470588234}
# {'_id': 'B00E4RZOQ0', 'value': 5.0}
# {'_id': 'B00E4RZQM2', 'value': 2.4285714285714284}
# {'_id': 'B00E4RZU00', 'value': 3.7857142857142856}
# {'_id': 'B00E4RZV6S', 'value': 3.75}
# {'_id': 'B00E4RZW44', 'value': 3.0}
# {'_id': 'B00E4RZYMO', 'value': 1.0}
# {'_id': 'B00E4S5BQ2', 'value': 5.0}
# {'_id': 'B00E4SDU0Q', 'value': 1.0}
# {'_id': 'B00E4SEBAY', 'value': 5.0}
# {'_id': 'B00E4SPPHW', 'value': 2.689655172413793}
# {'_id': 'B00E4T58NC', 'value': 3.206060606060606}
# {'_id': 'B00E4T699E', 'value': 3.0}
# {'_id': 'B00E4T69DK', 'value': 5.0}
# {'_id': 'B00E4T6MWI', 'value': 2.0}
# {'_id': 'B00E4T7GP0', 'value': 2.0}
# {'_id': 'B00E4T7VOG', 'value': 5.0}
# {'_id': 'B00E4T8XZC', 'value': 4.75}
# {'_id': 'B00E4TADN2', 'value': 3.0}
# {'_id': 'B00E4TASKK', 'value': 3.5}
# {'_id': 'B00E4TBST0', 'value': 5.0}
# {'_id': 'B00E4TEKC2', 'value': 5.0}
# {'_id': 'B00E4TKYOU', 'value': 5.0}
# {'_id': 'B00E4TN3MA', 'value': 1.0}
# {'_id': 'B00E4TOWR0', 'value': 3.0}
# {'_id': 'B00E4TV36I', 'value': 5.0}
# {'_id': 'B00E4TWMWC', 'value': 1.0}
# {'_id': 'B00E4U83B0', 'value': 2.7}
# {'_id': 'B00E4UA7SW', 'value': 4.769230769230769}
# {'_id': 'B00E4UD9TQ', 'value': 4.666666666666667}
# {'_id': 'B00E4UGIVC', 'value': 3.0}
# {'_id': 'B00E4UGJV6', 'value': 4.0}
# {'_id': 'B00E4UIU1I', 'value': 5.0}
# {'_id': 'B00E4UVVYG', 'value': 5.0}
